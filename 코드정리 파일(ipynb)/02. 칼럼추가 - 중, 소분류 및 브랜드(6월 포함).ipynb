# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
import seaborn as sns
import datetime
import pickle

import warnings
warnings.filterwarnings(action = 'ignore')

# %% [markdown]
# # 상품군별 브랜드 칼럼 추가

# %%
data = pd.read_excel('data/2020 빅콘테스트 데이터분석분야-챔피언리그_2019년 실적데이터_v1_200818.xlsx', header=1)
data
# Out:
#                      방송일시      노출(분)    마더코드    상품코드  \
# 0     2019-01-01 06:00:00  20.000000  100346  201072
# 1     2019-01-01 06:00:00        NaN  100346  201079
# 2     2019-01-01 06:20:00  20.000000  100346  201072
# 3     2019-01-01 06:20:00        NaN  100346  201079
# 4     2019-01-01 06:40:00  20.000000  100346  201072
# ...                   ...        ...     ...     ...
# 38304 2020-01-01 00:20:00  20.000000  100073  200196
# 38305 2020-01-01 00:40:00  20.000000  100073  200196
# 38306 2020-01-01 01:00:00  20.000000  100073  200196
# 38307 2020-01-01 01:20:00  20.000000  100490  201478
# 38308 2020-01-01 01:40:00  17.166667  100490  201478
#
#                             상품명 상품군   판매단가        취급액
# 0                 테이트 남성 셀린니트3종  의류  39900  2099000.0
# 1                 테이트 여성 셀린니트3종  의류  39900  4371000.0
# 2                 테이트 남성 셀린니트3종  의류  39900  3262000.0
# 3                 테이트 여성 셀린니트3종  의류  39900  6955000.0
# ...

# %%
data['브랜드'] = np.nan

# %% [markdown]
# ## 브랜드 - 의류

# %%
# 브랜드 - 의류
for i in range(len(data)):
    if data['상품군'][i]=='의류':
        data['브랜드'][i] = data['상품명'][i].split()[0]
data[data['상품군']=='의류']['브랜드'].unique()
# Out:
# array(['테이트', 'CERINI', '보코', '그렉노먼', '마리노블', '헤스티지', 'NNF', '아문센',
#        '마담팰리스', 'K-SWISS', '아리스토우', '도네이', '더블유베일', '로이몬스터', '임페리얼',
#        '메시제이', '크리스티나앤코', '루이바셋', '에르나벨', '엔셀라두스', '헤비추얼', '뱅뱅', '아주아',
#        '디키즈', '스텔라테일러', '19', '젠트웰', '마르엘라로사티', '오렐리안', 'USPA', '코몽트',
#        '릴리젼', '라라쎄', '타운젠트', '2019', '코펜하겐럭스', '알렉스하운드', '어반시크릿', '레드캠프',
#        '메이듀', 'EXR', '팜스프링스', '디즈니', '대동모피', '이동수골프', '[페플럼제이]', '[유리진]',
#        '디베이지', '마모트', 'USPA화이트라벨', '[EXR]', '[K-SWISS]', '[헤스티지]',
#        '스튜디오럭스', '[디즈니]', '19FW마리노블', '르까프'], dtype=object)

# %%
for i in range(len(data)):
    if data['상품군'][i]=='의류':
        if 'CERINI' in data['상품명'][i]:
            data['브랜드'][i] = 'CERINI by PAT'
        elif 'USPA' in data['상품명'][i]:
            data['브랜드'][i] = 'USPA'
        elif '디즈니' in data['상품명'][i]:
            data['브랜드'][i] = '디즈니'
        elif '페플럼제이' in data['상품명'][i]:
            data['브랜드'][i] = '페플럼제이'
        elif '유리진' in data['상품명'][i]:
            data['브랜드'][i] = '유리진'
        elif 'EXR' in data['상품명'][i]:
            data['브랜드'][i] = 'EXR'
        elif 'K-SWISS' in data['상품명'][i]:
            data['브랜드'][i] = 'K-SWISS'
        elif '헤스티지' in data['상품명'][i]:
            data['브랜드'][i] = '헤스티지' 
        elif '마리노블' in data['상품명'][i]:
            data['브랜드'][i] = '마리노블'

# %%
data[data['상품군']=='의류']['브랜드'].unique()
# Out:
# array(['테이트', 'CERINI by PAT', '보코', '그렉노먼', '마리노블', '헤스티지', 'NNF', '아문센',
#        '마담팰리스', 'K-SWISS', '아리스토우', '도네이', '더블유베일', '로이몬스터', '임페리얼',
#        '메시제이', '크리스티나앤코', '루이바셋', '에르나벨', '엔셀라두스', '헤비추얼', '뱅뱅', '아주아',
#        '디키즈', '스텔라테일러', 'USPA', '젠트웰', '마르엘라로사티', '오렐리안', '코몽트', '릴리젼',
#        '라라쎄', '타운젠트', '코펜하겐럭스', '알렉스하운드', '어반시크릿', '레드캠프', '메이듀', 'EXR',
#        '팜스프링스', '디즈니', '대동모피', '이동수골프', '페플럼제이', '유리진', '디베이지', '마모트',
#        '스튜디오럭스', '르까프'], dtype=object)

# %% [markdown]
# ## 브랜드 - 속옷

# %%
## 브랜드 - 속옷
for i in range(len(data)):
    if data['상품군'][i]=='속옷':
        data['브랜드'][i] = data['상품명'][i].split()[0]
data[data['상품군']=='속옷']['브랜드'].unique()
# Out:
# array(['오모떼', '크로커다일', '푸마', '로베르타', '레이프릴', '쿠미투니카', '에버라스트', '카파',
#        '몬테밀라노', '컬럼비아', '남영비비안', '헤스떼벨', '아키', '(ARS10%)크로커다일',
#        'BBC&IZUMI', '리복', '오렐리안', '뷰티플렉스', '실크트리', '헤드', '벨레즈온',
#        '초특가)에버라스트', '실크플러스', '댄스킨', '[라쉬반］FC바로셀로나', 'LSX라이크라', '오가닉뷰티',
#        '(일시불)헤드', '(무이자)헤드', '(세일20%)푸마', '라쉬반', '발레리', '란체티', '히트융',
#        '코몽트', '[완벽더블]오모떼', '루시헨느', '저스트마이사이즈'], dtype=object)

# %%
for i in range(len(data)):
    if data['상품군'][i]=='속옷':
        if '로베르타' in data['상품명'][i]:
            data['브랜드'][i] = '로베르타 디 까메리노'
        elif '크로커다일' in data['상품명'][i]:
            data['브랜드'][i] = '크로커다일'
        elif '에버라스트' in data['상품명'][i]:
            data['브랜드'][i] = '에버라스트'
        elif '실크플러스' in data['상품명'][i]:
            data['브랜드'][i] = '투홀릭'
        elif '라쉬반' in data['상품명'][i]:
            data['브랜드'][i] = '라쉬반'
        elif '헤드' in data['상품명'][i]:
            data['브랜드'][i] = '헤드'
        elif '푸마' in data['상품명'][i]:
            data['브랜드'][i] = '푸마'
        elif '오모떼' in data['상품명'][i]:
            data['브랜드'][i] = '오모떼'
        elif 'LSX' in data['상품명'][i]:
            data['브랜드'][i] = 'LSX'

# %%
data[data['상품군']=='속옷']['브랜드'].unique()
# Out:
# array(['오모떼', '크로커다일', '푸마', '로베르타 디 까메리노', '레이프릴', '쿠미투니카', '에버라스트',
#        '카파', '몬테밀라노', '컬럼비아', '남영비비안', '헤스떼벨', '아키', 'BBC&IZUMI', '리복',
#        '오렐리안', '뷰티플렉스', '실크트리', '헤드', '벨레즈온', '투홀릭', '댄스킨', '라쉬반', 'LSX',
#        '오가닉뷰티', '발레리', '란체티', '히트융', '코몽트', '루시헨느', '저스트마이사이즈'],
#       dtype=object)

# %% [markdown]
# ## 브랜드 - 주방

# %%
brands = [
'에코라믹',
'쿠첸',
'린나이',
'키친플라워',
'한일',
'쿠쿠',
'스위스밀리터리',
'모즈',
'아이오',
'락앤락',
'에버홈',
'올리고',
'해피콜',
'스텐락',
'쓰임',
'로벤탈',
'클레린',
'아이넥스',
'프로피쿡',
'키친아트',
'쿠진',
'에지리',
'노와',
'델첸',
'파뷔에',
'송도순',
'매직쉐프',
'테팔',
'글라스락',
'리큅',
'뉴욕맘',
'한샘',
'마이베비',
'휴롬',
'오스터',
'에코바이런',
'웰스락',
'하우홈',
'am마카롱',
'두꺼비',
'오슬로',
'안타고',
'이지엔',
'에델코첸',
'SK매직',
'실리만',
'IH',
'벨라홈',
'라니',
'풍년',
'비앙코 볼토',
'센스락',
'클란츠',
'구스터',
'실바트',
'셰프웨이',
'세라맥스',
'셀렉프로',
'옥샘쿡',
'램프쿡'
]

# %%
for i in range(len(data)):
    if data['상품군'][i] == '주방':
        data['브랜드'][i] = '기타_주방'

# %%
for i in range(len(data)):
    if data['상품군'][i] == '주방':
        for brand in brands:
            if brand in data['상품명'][i]:
                data['브랜드'][i] = brand

# %% [markdown]
# ## 브랜드 - 농수축

# %%
for i in range(len(data)):
    if data['상품군'][i]=='농수축':
        if '이봉원' in data['상품명'][i]:
            data['브랜드'][i] = '이봉원'
        elif '농협' in data['상품명'][i]:
            data['브랜드'][i] = '농협'
        elif '우리바다' in data['상품명'][i]:
            data['브랜드'][i] = '우리바다'
        elif '안동' in data['상품명'][i]:
            data['브랜드'][i] = '안동'
        elif '삼립' in data['상품명'][i]:
            data['브랜드'][i] = '삼립'
        elif '하림' in data['상품명'][i]:
            data['브랜드'][i] = '하림'
        elif '바다먹자' in data['상품명'][i]:
            data['브랜드'][i] = '바다먹자'
        elif '피시원' in data['상품명'][i]:
            data['브랜드'][i] = '피시원'
        elif '천연담아' in data['상품명'][i]:
            data['브랜드'][i] = '천연담아'
        elif '청정수산' in data['상품명'][i]:
            data['브랜드'][i] = '청정수산'
        elif '영산포' in data['상품명'][i]:
            data['브랜드'][i] = '영산포'
        elif '소들녘' in data['상품명'][i]:
            data['브랜드'][i] = '소들녘'
        elif '팽현숙' in data['상품명'][i]:
            data['브랜드'][i] = '팽현숙'
        elif '천수봉' in data['상품명'][i]:
            data['브랜드'][i] = '천수봉'        
        elif '수협' in data['상품명'][i]:
            data['브랜드'][i] = '수협'        
        elif '제주바다' in data['상품명'][i]:
            data['브랜드'][i] = '제주바다'
        elif '곡물그대로' in data['상품명'][i]:
            data['브랜드'][i] = '곡물그대로' 
        elif '장보고' in data['상품명'][i]:
            data['브랜드'][i] = '장보고'       
        elif '양구' in data['상품명'][i]:
            data['브랜드'][i] ='양구'       
        elif '카라카라' in data['상품명'][i]:
            data['브랜드'][i] = '카라카라'       
        elif '김정문' in data['상품명'][i]:
            data['브랜드'][i] = '김정문'
        elif '이만기' in data['상품명'][i]:
            data['브랜드'][i] = '이만기'    
        elif '본죽' in data['상품명'][i]:
            data['브랜드'][i] = '본죽'
        elif '영광' in data['상품명'][i]:
            data['브랜드'][i] = '영광'
        elif '유귀열' in data['상품명'][i]:
            data['브랜드'][i] ='유귀열'
        elif '최인선' in data['상품명'][i]:
            data['브랜드'][i] = '최인선'
        elif '바다원' in data['상품명'][i]:
            data['브랜드'][i] = '바다원'       
        elif 'LA갈비' in data['상품명'][i]:
            data['브랜드'][i] = 'LA갈비'      
        elif '맛있는 제주' in data['상품명'][i]:
            data['브랜드'][i] = '맛있는 제주'       
        elif '전철우' in data['상품명'][i]:
            data['브랜드'][i] = '전철우'       
        elif '이경제' in data['상품명'][i]:
            data['브랜드'][i] = '이경제'       
        elif '하동' in data['상품명'][i]:
            data['브랜드'][i] = '하동'        
        elif '창녕' in data['상품명'][i]:
            data['브랜드'][i] = '창녕'         
        elif '깐깐송도순' in data['상품명'][i]:
            data['브랜드'][i] = '깐깐송도순' 
        elif '임성근' in data['상품명'][i]:
            data['브랜드'][i] = '임성근'         
        elif '현대어찬' in data['상품명'][i]:
            data['브랜드'][i] = '현대어찬'         
        elif '예천청결' in data['상품명'][i]:
            data['브랜드'][i] = '예천청결'         
        elif '하늘내린' in data['상품명'][i]:
            data['브랜드'][i] = '하늘내린'         
        elif '김선영' in data['상품명'][i]:
            data['브랜드'][i] = '김선영'         
        elif '김규흔' in data['상품명'][i]:
            data['브랜드'][i] = '김규흔'       
        elif '신세대' in data['상품명'][i]:
            data['브랜드'][i] = '신세대'         
        elif '목우촌' in data['상품명'][i]:
            data['브랜드'][i] = '목우촌'         
        elif '김정배' in data['상품명'][i]:
            data['브랜드'][i] = '김정배'         
        elif '이보은' in data['상품명'][i]:
            data['브랜드'][i] = '이보은'         
        elif '슬로푸드' in data['상품명'][i]:
            data['브랜드'][i] = '슬로푸드'         
        elif '오세득' in data['상품명'][i]:
            data['브랜드'][i] = '오세득'        
        elif '강레오' in data['상품명'][i]:
            data['브랜드'][i] = '강레오'            
        elif '산머루농원 ' in data['상품명'][i]:
            data['브랜드'][i] = '산머루농원'
        elif '식탁앤김 ' in data['상품명'][i]:
            data['브랜드'][i] = '식탁앤김'
        elif '조방할매 ' in data['상품명'][i]:
            data['브랜드'][i] = '조방할매'
        elif '옛날 그 쥐포 ' in data['상품명'][i]:
            data['브랜드'][i] = '옛날 그 쥐포'
        elif '참바다 ' in data['상품명'][i]:
            data['브랜드'][i] = '참바다'
        elif '잔다리 ' in data['상품명'][i]:
            data['브랜드'][i] = '참바다'
        else:
            data['브랜드'][i] = '기타_농수축브랜드'

# %% [markdown]
# ## 브랜드 - 이미용

# %%
for i in range(len(data)):
    if data['상품군'][i]=='이미용':
        data['브랜드'][i] = data['상품명'][i].split()[0]

# %%
data[(data['상품군'] == '이미용') & (data['브랜드'].notnull())].shape   # 167개 확인
# Out:
# (1305, 9)

# %%
data[data['상품군']=='이미용']['브랜드'].unique()
# Out:
# array(['비버리힐스폴로클럽', '엘렌실라', '스포메틱스', '스칼프솔루션', '마리끌레르', '파시노', '달바',
#        '[살롱클리닉]샤이닝', '에이유플러스', '시크릿', 'NEW프리미엄', '에이온에이', '바바코코', '자올',
#        '참존', '라라츄', '엘로엘', '실크테라피', '[VONIN]보닌', '시크릿뮤즈', '아미니', '블링썸',
#        '코튼플러스', '엘렌실라&코즈미', '네오젠', '뉴웨이', '메디앤서', '아이앤아이', '미바', '프리미엄',
#        '더블모', 'AHC', '컨시크', '고데롤', '피부약방', '(일시불)엘렌실라&코즈미',
#        '(무이자)엘렌실라&코즈미'], dtype=object)

# %%
for i in range(len(data)):
    if data['상품군'][i]=='이미용':
        if data['브랜드'][i] == '[VONIN]보닌':
            data['브랜드'][i] = '보닌'
        elif data['브랜드'][i] == 'NEW프리미엄':
            data['브랜드'][i] = 'TS'
        elif ('(일시불)' in data['브랜드'][i]) or ('(무이자)' in data['브랜드'][i]):
            data['브랜드'][i] = '엘렌실라&코즈미'
        elif data['브랜드'][i] == '프리미엄':
            data['브랜드'][i] = '클린샤워'
        elif data['브랜드'][i] == '시크릿':
            data['브랜드'][i] = '라메종'
        elif data['브랜드'][i] == '[살롱클리닉]샤이닝':
            data['브랜드'][i] = '살롱클리닉'

# %%
data[data['상품군']=='이미용']['브랜드'].unique()
# Out:
# array(['비버리힐스폴로클럽', '엘렌실라', '스포메틱스', '스칼프솔루션', '마리끌레르', '파시노', '달바',
#        '살롱클리닉', '에이유플러스', '라메종', 'TS', '에이온에이', '바바코코', '자올', '참존', '라라츄',
#        '엘로엘', '실크테라피', '보닌', '시크릿뮤즈', '아미니', '블링썸', '코튼플러스', '엘렌실라&코즈미',
#        '네오젠', '뉴웨이', '메디앤서', '아이앤아이', '미바', '클린샤워', '더블모', 'AHC', '컨시크',
#        '고데롤', '피부약방'], dtype=object)

# %%
data[(data['상품군'] == '이미용') & (data['브랜드'].isnull())]
# Out:
# Empty DataFrame
# Columns: [방송일시, 노출(분), 마더코드, 상품코드, 상품명, 상품군, 판매단가, 취급액, 브랜드]
# Index: []

# %% [markdown]
# ## 브랜드 - 가전

# %%
for i in range(len(data)):
    if data['상품군'][i]=='가전':
        if '삼성' in data['상품명'][i]:
            data['브랜드'][i] = '삼성'
        elif 'LG' in data['상품명'][i]:
            data['브랜드'][i] = 'LG'
        elif '대우' in data['상품명'][i]:
            data['브랜드'][i] = '대우전자'
        elif '캐리어' in data['상품명'][i] and '김치' not in data['상품명'][i]:
            data['브랜드'][i] = '캐리어'
        elif '딤채' in data['상품명'][i]:
            data['브랜드'][i] = '딤채'
        else:
            data['브랜드'][i] = '기타_가전브랜드'

# %% [markdown]
# ##  브랜드 - 생활용품

# %%
# 생활용품 - 브랜드

for i in range(len(data)):
    if data['상품군'][i]=='생활용품':
        if '벨라홈' in data['상품명'][i]:
            data['브랜드'][i] = '벨라홈'
        elif '노비타' in data['상품명'][i]:
            data['브랜드'][i] = '노비타'
        elif '코이모' in data['상품명'][i]:
            data['브랜드'][i] = '코이모'
        elif '스위스밀리터리' in data['상품명'][i]:
            data['브랜드'][i] = '스위스밀리터리'
        elif '크린조이' in data['상품명'][i]:
            data['브랜드'][i] = '크린조이'
        elif '세렌셉템버' in data['상품명'][i]:
            data['브랜드'][i] = '세렌셉템버'
        elif '까사마루' in data['상품명'][i]:
            data['브랜드'][i] = '까사마루'
        elif '바로바로' in data['상품명'][i]:
            data['브랜드'][i] = '바로바로'
        elif '올바로' in data['상품명'][i]:
            data['브랜드'][i] = '올바로'
        elif 'LG생활건강' in data['상품명'][i]:
            data['브랜드'][i] = 'LG생활건강'
        elif '굿프렌드' in data['상품명'][i]:
            data['브랜드'][i] = '굿프렌드'
        elif '스피드랙' in data['상품명'][i]:
            data['브랜드'][i] = '스피드랙'
        elif '모리츠' in data['상품명'][i]:
            data['브랜드'][i] = '모리츠'
        elif '한일' in data['상품명'][i]:
            data['브랜드'][i] = '한일'
        elif '디비노' in data['상품명'][i]:
            data['브랜드'][i] = '디비노'
        elif '이지스' in data['상품명'][i]:
            data['브랜드'][i] = '이지스'
        elif '도루코' in data['상품명'][i]:
            data['브랜드'][i] = '도루코'
        elif '노송가구' in data['상품명'][i]:
            data['브랜드'][i] = '노송가구'
        elif '퀸메이드' in data['상품명'][i]:
            data['브랜드'][i] = '퀸메이드'
        elif '블루콤' in data['상품명'][i]:
            data['브랜드'][i] = '블루콤'
        elif '캐치온' in data['상품명'][i]:
            data['브랜드'][i] = '캐치온'
        elif '킹스스파' in data['상품명'][i]:
            data['브랜드'][i] = '킹스스파'
        elif '바두기' in data['상품명'][i]:
            data['브랜드'][i] = '바두기'
        elif '일월' in data['상품명'][i]:
            data['브랜드'][i] = '일월'
        elif '트라이' in data['상품명'][i]:
            data['브랜드'][i] = '트라이'
        elif '발렌티노루디' in data['상품명'][i]:
            data['브랜드'][i] = '발렌티노루디'
        elif '사운드룩' in data['상품명'][i]:
            data['브랜드'][i] = '사운드룩'
        elif '레스트업' in data['상품명'][i]:
            data['브랜드'][i] = '레스트업'
        elif '한솔' in data['상품명'][i]:
            data['브랜드'][i] = '한솔'
        elif '파로마' in data['상품명'][i]:
            data['브랜드'][i] = '파로마'
        elif '테팔' in data['상품명'][i]:
            data['브랜드'][i] = '테팔'
        elif '코지마' in data['상품명'][i]:
            data['브랜드'][i] = '코지마'
        elif '엑사이더' in data['상품명'][i]:
            data['브랜드'][i] = '엑사이더'
        elif '스칸디나비아' in data['상품명'][i]:
            data['브랜드'][i] = '스칸디나비아'
        elif 'KF94' in data['상품명'][i]:
            data['브랜드'][i] = 'KF94'
        elif '선일' in data['상품명'][i]:
            data['브랜드'][i] = '선일'
        elif '메디쉴드' in data['상품명'][i]:
            data['브랜드'][i] = '메디쉴드'
        elif '선일' in data['상품명'][i]:
            data['브랜드'][i] = '선일'
        elif '김병만' in data['상품명'][i]:
            data['브랜드'][i] = '김병만'
        elif '숀리' in data['상품명'][i]:
            data['브랜드'][i] = '숀리'
        elif '메디컬드림' in data['상품명'][i]:
            data['브랜드'][i] = '메디컬드림'
        elif '거미손' in data['상품명'][i]:
            data['브랜드'][i] = '거미손'
        elif '바로톡' in data['상품명'][i]:
            data['브랜드'][i] = '바로톡'
        elif '대웅' in data['상품명'][i]:
            data['브랜드'][i] = '대웅'
        elif '뚜러킹' in data['상품명'][i]:
            data['브랜드'][i] = '뚜러킹'
        elif '자미코코' in data['상품명'][i]:
            data['브랜드'][i] = '자미코코'
        elif '타이거' in data['상품명'][i]:
            data['브랜드'][i] = '타이거'
        elif '브람스' in data['상품명'][i]:
            data['브랜드'][i] = '브람스'
        elif '니봇' in data['상품명'][i]:
            data['브랜드'][i] = '니봇'
        elif '중외신약' in data['상품명'][i]:
            data['브랜드'][i] = '중외신약'
        elif '밀레' in data['상품명'][i]:
            data['브랜드'][i] = '밀레'
        elif '스팀큐' in data['상품명'][i]:
            data['브랜드'][i] = '스팀큐'
        elif '김병지' in data['상품명'][i]:
            data['브랜드'][i] = '김병지'
        elif '센스하우스' in data['상품명'][i]:
            data['브랜드'][i] = '센스하우스'
        elif '페르소나' in data['상품명'][i]:
            data['브랜드'][i] = '페르소나'
        elif '센티멘탈' in data['상품명'][i]:
            data['브랜드'][i] = '센티멘탈'
        elif '센스톰' in data['상품명'][i]:
            data['브랜드'][i] = '센스톰'
        elif '보국' in data['상품명'][i]:
            data['브랜드'][i] = '보국'
        elif '따스림' in data['상품명'][i]:
            data['브랜드'][i] = '따스림'
        elif '자미코코' in data['상품명'][i]:
            data['브랜드'][i] = '자미코코'
        elif '루미테라피' in data['상품명'][i]:
            data['브랜드'][i] = '루미테라피'
        elif '월시스' in data['상품명'][i]:
            data['브랜드'][i] = '월시스'
        elif '히팅맘' in data['상품명'][i]:
            data['브랜드'][i] = '히팅맘'
        elif '수련' in data['상품명'][i]:
            data['브랜드'][i] = '수련'
        elif '밸런스파워' in data['상품명'][i]:
            data['브랜드'][i] = '밸런스파워'
        elif '3D' in data['상품명'][i]:
            data['브랜드'][i] = '3D매쉬'
        elif '파워스윙' in data['상품명'][i]:
            data['브랜드'][i] = '파워스윙'
        elif 'OK' in data['상품명'][i]:
            data['브랜드'][i] = 'OK'
        elif '프리모' in data['상품명'][i]:
            data['브랜드'][i] = '프리모'
        elif '신일' in data['상품명'][i]:
            data['브랜드'][i] = '신일'
        elif '닥터웰' in data['상품명'][i]:
            data['브랜드'][i] = '닥터웰'
        elif '벨리슬립' in data['상품명'][i]:
            data['브랜드'][i] = '벨리슬립'
        elif '르젠' in data['상품명'][i]:
            data['브랜드'][i] = '르젠'
        elif '에레키반' in data['상품명'][i]:
            data['브랜드'][i] = '에레키반'
        elif '벤트리' in data['상품명'][i]:
            data['브랜드'][i] = '벤트리'
        elif '공간아트' in data['상품명'][i]:
            data['브랜드'][i] = '공간아트'
        elif '에브리빙' in data['상품명'][i]:
            data['브랜드'][i] = '에브리빙'
        elif '단순생활' in data['상품명'][i]:
            data['브랜드'][i] = '단순생활'
        elif '아룬싸왓' in data['상품명'][i]:
            data['브랜드'][i] = '아룬싸왓'

# %% [markdown]
# ## 브랜드 - 건강기능

# %%
for i in range(len(data)):
    if data['상품군'][i] == '건강기능':
        if ('뉴트리원' in data['상품명'][i]) or ('모나코' in data['상품명'][i]):
            data['브랜드'][i] = '뉴트리원'
        elif '블랙모어스' in data['상품명'][i]:
            data['브랜드'][i] = '블랙모어스'
        elif '더 리얼' in data['상품명'][i]:
            data['브랜드'][i] = '더리얼'
        elif '비에날씬' in data['상품명'][i]:
            data['브랜드'][i] = '비에날씬'
        elif '종근당' in data['상품명'][i]:
            data['브랜드'][i] = '종근당'
        elif '광동' in data['상품명'][i]:
            data['브랜드'][i] = '광동제약'
        elif '경남제약' in data['상품명'][i]:
            data['브랜드'][i] = '경남제약'
        elif '네페르티티' in data['상품명'][i]:
            data['브랜드'][i] = '네페르티티'
        elif '닥터' in data['상품명'][i]:
            data['브랜드'][i] = 'HL사이언스'
        elif '리얼니파팜' in data['상품명'][i]:
            data['브랜드'][i] = '리얼니파팜'
        elif '한삼인' in data['상품명'][i]:
            data['브랜드'][i] = '한삼인'
        elif '베지밀' in data['상품명'][i]:
            data['브랜드'][i] = '한삼인'
        elif '안국' in data['상품명'][i]:
            data['브랜드'][i] = '안국'
        elif '팥물' in data['상품명'][i]:
            data['브랜드'][i] = '티스토리'
        elif '이경제' in data['상품명'][i]:
            data['브랜드'][i] = '이경제'
        elif '정직한 농부' in data['상품명'][i]:
            data['브랜드'][i] = '정직한농부'
        elif '제주농장' in data['상품명'][i]:
            data['브랜드'][i] = '제주농장'
        elif '아임파인' in data['상품명'][i]:
            data['브랜드'][i] = '아미코젠'
        elif '이롬' in data['상품명'][i]:
            data['브랜드'][i] = '이롬'
        elif '티젠' in data['상품명'][i]:
            data['브랜드'][i] = '티젠'
            
        else:
            data['브랜드'][i] = '기타_건강기능'

# %% [markdown]
# ## 브랜드 - 잡화

# %%
brands=[
'가이거',
'메디아글램',
'안드레아바나',
'루이띠에',
'플로쥬',
'DIOR',
'RYN',
'로베르타',
'엘리자베스아덴',
'갈란테',
'골드파일',
'구찌',
'도스문도스',
'레노마',
'레코바',
'마스케라',
'마이클코어스',
'메이듀',
'썸덱스',
'바치',
'버버리',
'삭루츠',
'생쥴랑',
'세인트스코트',
'스프리스',
'시스마르스',
'아가타',
'아르테사노',
'알비에로',
'에버라스트',
'에트로',
'에펨',
'엘르',
'오델로',
'월드컵',
'제옥스',
'칼리베이직',
'코치',
'트레스패스',
'프라다',
'AAA',
'AAD',
'기라로쉬'
]

# %%
for i in range(len(data)):
    if data['상품군'][i]=='잡화':
        for brand in brands:
            if brand in data['상품명'][i]:
                data['브랜드'][i]=brand
        if '생줄랑' in data['상품명'][i]:
            data['브랜드'][i]='생쥴랑'

# %% [markdown]
# ## 브랜드 - 가구

# %%
for i in range(len(data)):
    if data['상품군'][i]=='가구':
        data['브랜드'][i] = data['상품명'][i].split()[0]

# %%
data[(data['상품군'] == '가구') & (data['브랜드'].notnull())].shape   # 167개 확인
# Out:
# (2614, 9)

# %%
data[data['상품군']=='가구']['브랜드'].unique()
# Out:
# array(['보루네오', '(일)', '(무)', '(일)한샘', '(무)한샘', '(일)3인용', '(무)3인용',
#        '(일)4인용', '(무)4인용', '무)', '일)한샘', '무)한샘', '(일)보루네오', '(무)보루네오',
#        '(일)장수흙침대', '(무)장수흙침대', '(일)[보루네오]', '(무)[보루네오]', '무)이누스바스',
#        '일)이누스바스', '(일)삼익가구', '(무)삼익가구', '뉴', '이조농방', '[SET]이조농방', '레스토닉',
#        '(일)이누스바스', '(무)이누스바스', '유캐슬', '(일)장수', '(무)장수'], dtype=object)

# %%
for i in range(len(data)):
    if data['상품군'][i]=='가구':
        if (data['브랜드'][i] == '(일)'):
            data['브랜드'][i] = '삼익가구'
        elif (data['브랜드'][i] == '(무)') and ('한샘' not in data['상품명'][i]):
            data['브랜드'][i] = '삼익가구'
        elif (data['브랜드'][i] == '(무)') and ('삼익가구' not in data['상품명'][i]):
            data['브랜드'][i] = '한샘'
        elif (data['브랜드'][i] == '(일)3인용') or (data['브랜드'][i] == '(무)3인용'):
            data['브랜드'][i] = '한샘'
        elif (data['브랜드'][i] == '(일)4인용') or (data['브랜드'][i] == '(무)4인용'):
            data['브랜드'][i] = '한샘'
        elif (data['브랜드'][i] == '무)'):
            data['브랜드'][i] = '한샘'
        elif (data['브랜드'][i] == '뉴'):
            data['브랜드'][i] = '벨라홈'
        elif (data['브랜드'][i] == '[SET]이조농방'):
            data['브랜드'][i] = '이조농방'
        elif (data['브랜드'][i] == '(일)[보루네오]') or (data['브랜드'][i] == '(무)[보루네오]'):
            data['브랜드'][i] = '보루네오'
        elif (data['브랜드'][i] == '(일)장수흙침대') or (data['브랜드'][i] == '(무)장수흙침대'):
            data['브랜드'][i] = '장수'

# %%
data[data['상품군']=='가구']['브랜드'].unique()
# Out:
# array(['보루네오', '삼익가구', '(일)한샘', '(무)한샘', '한샘', '일)한샘', '무)한샘', '(일)보루네오',
#        '(무)보루네오', '장수', '무)이누스바스', '일)이누스바스', '(일)삼익가구', '(무)삼익가구', '벨라홈',
#        '이조농방', '레스토닉', '(일)이누스바스', '(무)이누스바스', '유캐슬', '(일)장수', '(무)장수'],
#       dtype=object)

# %%
for i in range(len(data)):
    if data['상품군'][i]=='가구':
        if '(일)' in data['브랜드'][i]:
            data['브랜드'][i] = data['브랜드'][i].replace('(일)','')
        elif '(무)' in data['브랜드'][i]:
            data['브랜드'][i] = data['브랜드'][i].replace('(무)','')
        elif '일)' in data['브랜드'][i]:
            data['브랜드'][i] = data['브랜드'][i].replace('일)','')
        elif '무)' in data['브랜드'][i]:
            data['브랜드'][i] = data['브랜드'][i].replace('무)','')
        elif '무)' in data['브랜드'][i]:
            data['브랜드'][i] = data['브랜드'][i].replace('무)','')

# %%
data[data['상품군']=='가구']['브랜드'].unique()
# Out:
# array(['보루네오', '삼익가구', '한샘', '장수', '이누스바스', '벨라홈', '이조농방', '레스토닉', '유캐슬'],
#       dtype=object)

# %%
data[(data['상품군'] == '가구') & (data['브랜드'].isnull())]
# Out:
# Empty DataFrame
# Columns: [방송일시, 노출(분), 마더코드, 상품코드, 상품명, 상품군, 판매단가, 취급액, 브랜드]
# Index: []

# %% [markdown]
# ## 브랜드 - 침구

# %%
# 침구 - 브랜드

for i in range(len(data)):
    if data['상품군'][i]=='침구':
        if '보몽드' in data['상품명'][i]:
            data['브랜드'][i] = '보몽드'
        elif '한샘' in data['상품명'][i]:
            data['브랜드'][i] = '한샘'
        elif '리앤코리아' in data['상품명'][i]:
            data['브랜드'][i] = '리앤'
        elif '효재' in data['상품명'][i]:
            data['브랜드'][i] = '효재'
        elif '안지' in data['상품명'][i]:
            data['브랜드'][i] = '안지'
        elif '한빛' in data['상품명'][i]:
            data['브랜드'][i] = '한빛'
        elif '리앤' in data['상품명'][i]:
            data['브랜드'][i] = '리앤'
        elif '지나송' in data['상품명'][i]:
            data['브랜드'][i] = '지나송'
        elif '한스데코' in data['상품명'][i]:
            data['브랜드'][i] = '한스데코'

# %%
data.head(30)
# Out:
#                   방송일시  노출(분)    마더코드    상품코드                            상품명  \
# 0  2019-01-01 06:00:00   20.0  100346  201072                  테이트 남성 셀린니트3종
# 1  2019-01-01 06:00:00    NaN  100346  201079                  테이트 여성 셀린니트3종
# 2  2019-01-01 06:20:00   20.0  100346  201072                  테이트 남성 셀린니트3종
# 3  2019-01-01 06:20:00    NaN  100346  201079                  테이트 여성 셀린니트3종
# 4  2019-01-01 06:40:00   20.0  100346  201072                  테이트 남성 셀린니트3종
# 5  2019-01-01 06:40:00    NaN  100346  201079                  테이트 여성 셀린니트3종
# 6  2019-01-01 07:00:00   20.0  100305  200974               오모떼 레이스 파운데이션 브라
# 7  2019-01-01 07:20:00   20.0  100305  200974               오모떼 레이스 파운데이션 브라
# 8  2019-01-01 07:40:00   20.0  100305  200974               오모떼 레이스 파운데이션 브라
# 9  2019-01-01 08:00:00   20.0  100808  202377  CERINI by PAT 남성 소프트 기모 릴렉스팬츠
# 10 2019-01-01 08:20:00   20.0  100808  202377  CERINI by PAT 남성 소프트 기모 릴렉스팬츠
# ...

# %% [markdown]
# # 상품군별 중분류, 소분류 칼럼 추가

# %%
data['중분류'] = np.nan
data['소분류'] = np.nan
data.head()
# Out:
#                  방송일시  노출(분)    마더코드    상품코드            상품명 상품군   판매단가  \
# 0 2019-01-01 06:00:00   20.0  100346  201072  테이트 남성 셀린니트3종  의류  39900
# 1 2019-01-01 06:00:00    NaN  100346  201079  테이트 여성 셀린니트3종  의류  39900
# 2 2019-01-01 06:20:00   20.0  100346  201072  테이트 남성 셀린니트3종  의류  39900
# 3 2019-01-01 06:20:00    NaN  100346  201079  테이트 여성 셀린니트3종  의류  39900
# 4 2019-01-01 06:40:00   20.0  100346  201072  테이트 남성 셀린니트3종  의류  39900
#
#          취급액  브랜드  중분류  소분류
# 0  2099000.0  테이트  NaN  NaN
# 1  4371000.0  테이트  NaN  NaN
# 2  3262000.0  테이트  NaN  NaN
# 3  6955000.0  테이트  NaN  NaN
# 4  6672000.0  테이트  NaN  NaN

# %% [markdown]
# ## 분류 - 의류

# %%
# 분류 시작

for i in range(len(data)):
    if data['상품군'][i] == '의류':
        if ('남녀' in data['상품명'][i]):
            data['중분류'][i] = '캐주얼/유니섹스'
        
        elif '남성' in data['상품명'][i]:
            data['중분류'][i] = '남성의류'
            
        elif '여성' in data['상품명'][i]:
            data['중분류'][i] = '여성의류'
        
        elif ('성인' in data['상품명'][i]):
            data['중분류'][i] = '캐주얼/유니섹스'
            
        elif ('밍크' in data['상품명'][i]) or ('양가죽' in data['상품명'][i]) or ('모피' in data['상품명'][i]) or ('무스탕' in data['상품명'][i]):
            data['중분류'][i] = '여성의류'
            
        elif '블라우스' in data['상품명'][i]:
            data['중분류'][i] = '여성의류'
        
        elif '아동' in data['상품명'][i]:
            data['중분류'][i] = '아동의류'
            data['소분류'][i] = '아동의류'
        
        elif '코몽트' in data['상품명'][i]:
            data['중분류'][i] = '남성의류'
            
        elif '젠트웰' in data['상품명'][i]:
            data['중분류'][i] = '남성의류'
               
        elif '크리스티나앤코' in data['상품명'][i]:
            data['중분류'][i] = '여성의류'
            
        elif '마르엘라로사티' in data['상품명'][i]:
            data['중분류'][i] = '여성의류'
            
        elif '보코' in data['상품명'][i]:
            data['중분류'][i] = '여성의류'
        
        elif 'NNF' in data['상품명'][i]:
            data['중분류'][i] = '여성의류'
            
        elif '페플럼제이' in data['상품명'][i]:
            data['중분류'][i] = '여성의류'
            
        elif '더블유베일' in data['상품명'][i]:
            data['중분류'][i] = '여성의류'
            
        elif '스튜디오럭스' in data['상품명'][i]:
            data['중분류'][i] = '여성의류'
        
        elif ('디즈니' in data['상품명'][i]):
            data['중분류'][i] = '캐주얼/유니섹스'
            
        elif ('USPA' in data['상품명'][i]):
            data['중분류'][i] = '캐주얼/유니섹스'
        
        elif ('알렉스하운드' in data['상품명'][i]):
            data['중분류'][i] = '캐주얼/유니섹스'
        
        elif ('디키즈' in data['상품명'][i]):
            data['중분류'][i] = '캐주얼/유니섹스'
        
        else:
            data['중분류'][i] = '여성의류'
            

for i in range(len(data)):
    if data['중분류'][i] == '여성의류':
        if ('밍크' in data['상품명'][i]) or ('양가죽' in data['상품명'][i]) or ('모피' in data['상품명'][i]) or ('무스탕' in data['상품명'][i]):
            data['소분류'][i] = '가죽/모피/무스탕'
            
        elif ('자켓' in data['상품명'][i]) or ('재킷' in data['상품명'][i]) or ('점퍼' in data['상품명'][i]) or ('코트' in data['상품명'][i]) or ('패딩' in data['상품명'][i]) or ('다운' in data['상품명'][i]):
            data['소분류'][i] = '자켓/점퍼/코트'
        
        elif ('니트' in data['상품명'][i]) or ('가디건' in data['상품명'][i]) or ('베스트' in data['상품명'][i]) or ('스웨터' in data['상품명'][i]) or ('앙상블' in data['상품명'][i]):
            data['소분류'][i] = '니트/가디건'
            
        elif ('블라우스' in data['상품명'][i]) or ('셔츠' in data['상품명'][i]) or ('쉬폰' in data['상품명'][i]):
            data['소분류'][i] = '블라우스/셔츠'
        
        elif ('스커트' in data['상품명'][i]):
            data['소분류'] = '스커트'
            
        elif ('원피스' in data['상품명'][i]):
            data['소분류'][i] = '원피스'
        
        elif ('티셔츠' in data['상품명'][i]) or ('터틀넥' in data['상품명'][i]) or ('맨투맨' in data['상품명'][i]) or ('기모티' in data['상품명'][i]) or ('모크넥' in data['상품명'][i]):
            data['소분류'][i] = '티셔츠'
            
        elif ('팬츠' in data['상품명'][i]) or ('데님' in data['상품명'][i]):
            data['소분류'][i] = '팬츠/데님'
        
        elif ('액티비티' in data['상품명'][i]) or ('트레이닝' in data['상품명'][i]) or ('트랙수트' in data['상품명'][i]) or ('라운지웨어' in data['상품명'][i]) or ('마모트' in data['상품명'][i]) or ('EXR' in data['상품명'][i]) or ('이지웨어' in data['상품명'][i]):
            data['소분류'][i] = '트레이닝'
            
        elif ('풀코디' in data['상품명'][i]) or ('세트' in data['상품명'][i]):
            data['소분류'][i] = '세트'
        else:
            data['소분류'][i] = '기타_여성의류'
            

            
for i in range(len(data)):
    if data['중분류'][i] == '남성의류':
        if ('가디건' in data['상품명'][i]):
            data['소분류'][i] = '가디건'
        
        elif ('니트' in data['상품명'][i]) or ('스웨터' in data['상품명'][i]):
            data['소분류'][i] = '니트/가디건'
            
        elif ('팬츠' in data['상품명'][i]) or ('데님' in data['상품명'][i]):
            data['소분류'][i] = '팬츠/데님'
            
        elif ('티셔츠' in data['상품명'][i]) or ('터틀넥' in data['상품명'][i]) or ('맨투맨' in data['상품명'][i]) or ('기모티' in data['상품명'][i]) or ('모크넥' in data['상품명'][i]):
            data['소분류'][i] = '티셔츠'
            
        elif('셔츠' in data['상품명'][i]) or ('남방' in data['상품명'][i]):
            data['소분류'][i] = '셔츠/남방'
            
        elif ('베스트' in data['상품명'][i]) or ('조끼' in data['상품명'][i]):
            data['소분류'][i] = '베스트/조끼'
            
        elif ('자켓' in data['상품명'][i]) or ('재킷' in data['상품명'][i]) or ('점퍼' in data['상품명'][i]) or ('코트' in data['상품명'][i]) or ('패딩' in data['상품명'][i]) or ('다운' in data['상품명'][i]):
            data['소분류'][i] = '자켓/점퍼/코트'
        

            
        
        
#         elif ('액티비티' in data['상품명'][i]) or ('트레이닝' in data['상품명'][i]) or ('트랙수트' in data['상품명'][i]) or ('라운지웨어' in data['상품명'][i]) or ('마모트' in data['상품명'][i]) or ('EXR' in data['상품명'][i]) or ('이지웨어' in data['상품명'][i]):
#             data['소분류'][i] = '트레이닝'
            
#         elif ('풀코디' in data['상품명'][i]) or ('세트' in data['상품명'][i]):
#             data['소분류'][i] = '세트'
        else:
            data['소분류'][i] = '트레이닝'
            

            
for i in range(len(data)):
    if data['중분류'][i] == '캐주얼/유니섹스':
        if ('가디건' in data['상품명'][i]):
            data['소분류'][i] = '가디건'
        
        elif ('니트' in data['상품명'][i]) or ('스웨터' in data['상품명'][i]):
            data['소분류'][i] = '니트/가디건'
            
        elif ('팬츠' in data['상품명'][i]) or ('데님' in data['상품명'][i]):
            data['소분류'][i] = '팬츠/데님'
            
        elif('셔츠' in data['상품명'][i]) or ('남방' in data['상품명'][i]):
            data['소분류'][i] = '셔츠/남방'
            
        elif ('베스트' in data['상품명'][i]) or ('조끼' in data['상품명'][i]):
            data['소분류'][i] = '베스트/조끼'
            
        elif ('자켓' in data['상품명'][i]) or ('재킷' in data['상품명'][i]) or ('점퍼' in data['상품명'][i]) or ('코트' in data['상품명'][i]) or ('패딩' in data['상품명'][i]) or ('다운' in data['상품명'][i]) or ('윈드브레이커' in data['상품명'][i]):
            data['소분류'][i] = '자켓/점퍼/코트'
        
        elif ('티셔츠' in data['상품명'][i]) or ('터틀넥' in data['상품명'][i]) or ('맨투맨' in data['상품명'][i]) or ('기모티' in data['상품명'][i]) or ('모크넥' in data['상품명'][i]):
            data['소분류'][i] = '티셔츠'
            
        elif ('액티비티' in data['상품명'][i]) or ('트레이닝' in data['상품명'][i]) or ('트랙수트' in data['상품명'][i]) or ('라운지웨어' in data['상품명'][i]) or ('이지웨어' in data['상품명'][i]) or ('멀티웨어' in data['상품명'][i]):
            data['소분류'][i] = '트레이닝'
        
        elif ('세트' in data['상품명'][i]):
            data['소분류'][i] = '세트'
        
        else:
            data['소분류'][i] = '기타_캐주얼'

# %% [markdown]
# ## 분류 - 속옷

# %%
# 분류 시작
# 중분류 나누기
for i in range(len(data)):
    if data['상품군'][i] == '속옷':
        if ('여성' in data['상품명'][i]):
            data['중분류'][i] = '여성속옷'
        
        elif '남성' in data['상품명'][i]:
            data['중분류'][i] = '남성속옷'
        
        # 아동속옷
        if ('여아' in data['상품명'][i]) or ('남아' in data['상품명'][i]):
            data['중분류'][i] = '아동속옷'
            data['소분류'][i] = '아동속옷'
            
        # 여성 브라팬티세트
        elif ('브라팬티' in data['상품명'][i]) or ('브래팬티' in data['상품명'][i]) or ('레이스 패키지' in data['상품명'][i]):
            data['중분류'][i] = '여성속옷'
            data['소분류'][i] = '브라팬티세트'
        
        # 여성 브래지어
        elif ('브라' in data['상품명'][i]):
            data['중분류'][i] = '여성속옷'
            data['소분류'][i] = '브래지어'
            
        # 여성 팬티
        # 메인에는 팬티가 여자 팬티만 있음.
        elif ('팬티' in data['상품명'][i]):
            data['중분류'][i] = '여성속옷'
            data['소분류'][i] = '팬티'
            
        # 여성 이지웨어/잠옷
        # 이지웨어도 여성만 존재
        elif ('원피스' in data['상품명'][i]) or ('이지웨어' in data['상품명'][i]):
            data['중분류'][i] = '여성속옷'
            data['소분류'][i] = '이지웨어/잠옷'
            
        # 여성 란쥬/쉐이퍼
        elif ('란쥬' in data['상품명'][i]) or ('쉐이퍼' in data['상품명'][i]):
            data['중분류'][i] = '여성속옷'
            data['소분류'][i] = '란쥬/쉐이퍼'
            
        # 여성 런닝/내의
        elif ('여성' in data['상품명'][i]) & ('내의' in data['상품명'][i]):
            data['중분류'][i] = '여성속옷'
            data['소분류'][i] = '런닝/내의'
        
        # 여성 런닝/내의
        elif ('보정런닝' in data['상품명'][i]) or ('이지탑' in data['상품명'][i]) or ('슬리머' in data['상품명'][i]):
            data['중분류'][i] = '여성속옷'
            data['소분류'][i] = '런닝/내의'
        
        # 여성 레깅스
        elif ('레깅스' in data['상품명'][i]):
            data['중분류'][i] = '여성속옷'
            data['소분류'][i] = '레깅스'
        
              
        # 남성 드로즈
        elif ('드로즈' in data['상품명'][i]):
            data['중분류'][i] = '남성속옷'
            data['소분류'][i] = '드로즈'
            
        # 남성 트렁크팬티    
        elif ('트렁크' in data['상품명'][i]):
            data['중분류'][i] = '남성속옷'
            data['소분류'][i] = '트렁크팬티'
            
        # 남성 런닝/내의
        elif ('남성' in data['상품명'][i]) & ('내의' in data['상품명'][i]):
            data['중분류'][i] = '남성속옷'
            data['소분류'][i] = '런닝/내의'
            
        
        # 남성 언더셔츠
        elif ('언더셔츠' in data['상품명'][i]):
            data['중분류'][i] = '남성속옷'
            data['소분류'][i] = '언더셔츠'
            
            
        # 브랜드 포함
        # 남성 런닝/내의 코몽트, 카파, 리복
        elif ('코몽트' in data['상품명'][i]) or ('카파' in data['상품명'][i]) or ('푸마' in data['상품명'][i]) or ('리복' in data['상품명'][i]):
            data['중분류'][i] = '남성속옷'
            data['소분류'][i] = '런닝/내의'
            
        elif ('오렐리안 히트모' in data['상품명'][i]):
            data['중분류'][i] = '여성속옷'
            data['소분류'][i] = '런닝/내의'
        
        elif ('오모떼 모달 웜' in data['상품명'][i]):
            data['중분류'][i] = '여성속옷'
            data['소분류'][i] = '런닝/내의'
            
        
        # 나머지 처리
        elif ('남성' in data['상품명'][i]) & ('베이스레이어' in data['상품명'][i]):
            data['중분류'][i] = '남성속옷'
            data['소분류'][i] = '런닝/내의'
            
        elif ('여성' in data['상품명'][i]) & ('베이스레이어' in data['상품명'][i]):
            data['중분류'][i] = '여성속옷'
            data['소분류'][i] = '런닝/내의'

            
        else:
            data['중분류'][i] = '기타_속옷'
            data['소분류'][i] = '기타_속옷_소분류'

# %% [markdown]
# ## 분류 - 주방

# %%
# 분류 나누기
for i in range(len(data)):
    if data['상품군'][i] == '주방':
        
        # 주방용품/식기
        if ('냄비' in data['상품명'][i]) or ('압력솥' in data['상품명'][i]) or ('가마솥' in data['상품명'][i]):
            data['중분류'][i] = '주방용품/식기'
            data['소분류'][i] = '냄비/압력솥'
            
        elif ('밀폐용기' in data['상품명'][i]) or ('용기' in data['상품명'][i]):
            data['중분류'][i] = '주방용품/식기'
            data['소분류'][i] = '물병/보관/밀폐용기'
        
        elif ('보온' in data['상품명'][i]) or ('텀블러' in data['상품명'][i]):
            data['중분류'][i] = '주방용품/식기'
            data['소분류'][i] = '보온/보냉/야외용품'
        
        elif ('프라이팬' in data['상품명'][i]) or ('후라이팬' in data['상품명'][i]) or ('실버팬' in data['상품명'][i]) or ('양면팬' in data['상품명'][i]):
            data['중분류'][i] = '주방용품/식기'
            data['소분류'][i] = '프라이팬'
            
        elif ('수세미' in data['상품명'][i]) or ('행주' in data['상품명'][i]) or ('지퍼백' in data['상품명'][i]) or ('그린 후레쉬' in data['상품명'][i]):
            data['중분류'][i] = '주방용품/식기'
            data['소분류'][i] = '주방잡화'
            
        elif ('도마' in data['상품명'][i]) or ('칼' in data['상품명'][i]) or ('소쿠리' in data['상품명'][i]):
            data['중분류'][i] = '주방용품/식기'
            data['소분류'][i] = '조리도구'
            
        elif ('식기건조대' in data['상품명'][i]) or ('싱크선반' in data['상품명'][i]):
            data['중분류'][i] = '주방용품/식기'
            data['소분류'][i] = '주방수납/싱크대정리용품'
            
        elif ('홈세트' in data['상품명'][i]) or ('디너세트' in data['상품명'][i]):
            data['중분류'][i] = '주방용품/식기'
            data['소분류'][i] = '식기/홈세트'
            
            
        # 주방가전    
        elif ('가스레인지' in data['상품명'][i]) or ('전기레인지' in data['상품명'][i]) or ('가스와이드그릴레인지' in data['상품명'][i]) or ('인덕션' in data['상품명'][i]) or ('전기렌인지' in data['상품명'][i]):
            data['중분류'][i] = '주방가전'
            data['소분류'][i] = '가스/전기레인지'
            
        elif ('믹서기' in data['상품명'][i]) or ('블렌더' in data['상품명'][i]) or ('착즙기' in data['상품명'][i]) or ('맷돌' in data['상품명'][i]) or ('스퀴저' in data['상품명'][i]) or ('다지기' in data['상품명'][i]):
            data['중분류'][i] = '주방가전'
            data['소분류'][i] = '믹서/분쇄기'
        
        elif ('식기세척기' in data['상품명'][i]) or ('건조기' in data['상품명'][i]):
            data['중분류'][i] = '주방가전'
            data['소분류'][i] = '식기세척기/건조기'
        
        elif ('전기밥솥' in data['상품명'][i]) or ('압력밥솥' in data['상품명'][i]):
            data['중분류'][i] = '주방가전'
            data['소분류'][i] = '전기밥솥'
            
        elif ('전자레인지' in data['상품명'][i]) or ('오븐' in data['상품명'][i]):
            data['중분류'][i] = '주방가전'
            data['소분류'][i] = '전자레인지/오븐'
        
        elif ('커피머신' in data['상품명'][i]):
            data['중분류'][i] = '주방가전'
            data['소분류'][i] = '커피머신'
            
        elif ('에어프라이어' in data['상품명'][i]) or ('그릴' in data['상품명'][i]) or ('티포트' in data['상품명'][i]) or ('티메이커' in data['상품명'][i]) or ('멀티쿡' in data['상품명'][i]) or ('죽제조기' in data['상품명'][i]) or ('중탕기' in data['상품명'][i]):
            data['중분류'][i] = '주방가전'
            data['소분류'][i] = '조리/가열기기'
            
        elif ('진공포장기' in data['상품명'][i]):
            data['중분류'][i] = '주방가전'
            data['소분류'][i] = '진공포장기'
        
        
         
        
        
        # 기타_주방
        else:
            data['중분류'][i] = '기타_주방'
            data['소분류'][i] = '기타_주방_소분류'

# %% [markdown]
# ## 분류 - 농수축

# %%
# 분류 시작


for i in range(len(data)):
    if data['상품군'][i] == '농수축':
        
        # 농산
        if ('사과' in data['상품명'][i]) or ('오렌지' in data['상품명'][i]) or ('한라봉' in data['상품명'][i]) or ('샤인머스켓' in data['상품명'][i]) or ('감말랭이' in data['상품명'][i]):
            data['중분류'][i] = '농산'
            data['소분류'][i] = '과일'
            
        elif ('고구마' in data['상품명'][i]) or ('옥수수' in data['상품명'][i]) or ('시래기' in data['상품명'][i]):
            data['중분류'][i] = '농산'
            data['소분류'][i] = '채소'
            
        elif ('햅쌀' in data['상품명'][i]) or ('쌀' in data['상품명'][i]):
            data['중분류'][i] = '농산'
            data['소분류'][i] = '쌀/잡곡/견과'
            
        # 수산
        elif ('생선' in data['상품명'][i]) or ('고등어' in data['상품명'][i]) or ('바다장어' in data['상품명'][i]) or ('홍어' in data['상품명'][i]) or ('수산물' in data['상품명'][i]) or ('조기' in data['상품명'][i]) or ('굴비' in data['상품명'][i]) or ('병어' in data['상품명'][i]) or ('가자미' in data['상품명'][i]) or ('옥돔' in data['상품명'][i]) or ('대구' in data['상품명'][i]) or ('갈치' in data['상품명'][i]):
            data['중분류'][i] = '수산'
            data['소분류'][i] = '생선류'
            
        elif ('꽃게' in data['상품명'][i]) or ('문어' in data['상품명'][i]) or ('랍스터' in data['상품명'][i]) or ('낙지' in data['상품명'][i]) or ('전복' in data['상품명'][i]) or ('골뱅이' in data['상품명'][i]) or ('참굴' in data['상품명'][i]) or ('오징어' in data['상품명'][i]) or ('꼬막' in data['상품명'][i]) or ('새우' in data['상품명'][i]):
            data['중분류'][i] = '수산'
            data['소분류'][i] = '해산물'
        
        elif ('황태' in data['상품명'][i]) or ('아구채' in data['상품명'][i]) or ('쥐포' in data['상품명'][i]) or ('과메기' in data['상품명'][i]):
            data['중분류'][i] = '수산'
            data['소분류'][i] = '건어물'
            
        elif ('매생이' in data['상품명'][i]) or ('식탁앤김' in data['상품명'][i]) or ('부각' in data['상품명'][i]) or ('다시팩' in data['상품명'][i]):
            data['중분류'][i] = '수산'
            data['소분류'][i] = '해조류'
        
        # 축산
        elif ('LA갈비' in data['상품명'][i]) or ('소갈비살' in data['상품명'][i]) or ('치마살' in data['상품명'][i]) or ('우삼겹' in data['상품명'][i]) or ('우삽겹' in data['상품명'][i]) or ('안창살' in data['상품명'][i]):
            data['중분류'][i] = '축산'
            data['소분류'][i] = '소고기'
        
        elif ('순대' in data['상품명'][i]) or ('소곱창' in data['상품명'][i]) or ('닭발' in data['상품명'][i]):
            data['중분류'][i] = '축산'
            data['소분류'][i] = '축산가공식품'
            
        elif ('오리로스' in data['상품명'][i]):
            data['중분류'][i] = '축산'
            data['소분류'][i] = '오리고기'
            
        elif ('곰탕' in data['상품명'][i]) or ('한우 한판' in data['상품명'][i]) or ('소한마리' in data['상품명'][i]) or ('돼지왕구이' in data['상품명'][i]) or ('장조림' in data['상품명'][i]) or ('치킨스테이크' in data['상품명'][i]) or ('낙곱새' in data['상품명'][i]) or ('도가니탕' in data['상품명'][i]) or ('감자탕' in data['상품명'][i]) or ('국밥' in data['상품명'][i]) or ('삼계탕' in data['상품명'][i]) or ('탕요일' in data['상품명'][i]) or ('갈비탕' in data['상품명'][i]):
            data['중분류'][i] = '축산'
            data['소분류'][i] = '축산가공식품'
        
        
        # 가공식품
        # 김치/반찬
        elif ('김치' in data['상품명'][i]):
            data['중분류'][i] = '가공식품'
            data['소분류'][i] = '김치/반찬'
            
        elif ('젓갈' in data['상품명'][i]):
            data['중분류'][i] = '가공식품'
            data['소분류'][i] = '김치/반찬'
            
        # 과자/간식
        elif ('떡' in data['상품명'][i]) or ('호빵' in data['상품명'][i]):
            data['중분류'][i] = '가공식품'
            data['소분류'][i] = '과자/간식'
            
        elif ('곡물그대로' in data['상품명'][i]) or ('맛밤' in data['상품명'][i]):
            data['중분류'][i] = '가공식품'
            data['소분류'][i] = '과자/간식'
            
        elif ('강정' in data['상품명'][i]):
            data['중분류'][i] = '가공식품'
            data['소분류'][i] = '과자/간식'
            
        # 라면/면/스프
        elif ('콩국수' in data['상품명'][i]):
            data['중분류'][i] = '가공식품'
            data['소분류'][i] = '라면/면/스프'
            
        # 조미료/소스/장류
        elif ('고춧가루' in data['상품명'][i]):
            data['중분류'][i] = '가공식품'
            data['소분류'][i] = '조미료/소스/장류'
            
        elif ('메주' in data['상품명'][i]):
            data['중분류'][i] = '가공식품'
            data['소분류'][i] = '조미료/소스/장류'
        
        # 커피/생수/음료
        elif ('두유' in data['상품명'][i]):
            data['중분류'][i] = '가공식품'
            data['소분류'][i] = '커피/생수/음료'
        
        # 전통건강
        elif ('아카시아꿀' in data['상품명'][i]) or ('벌꿀' in data['상품명'][i]):
            data['중분류'][i] = '가공식품'
            data['소분류'][i] = '전통건강'
            
        elif ('배즙' in data['상품명'][i]):
            data['중분류'][i] = '가공식품'
            data['소분류'][i] = '전통건강'
            
        elif ('매실원액' in data['상품명'][i]) or ('머루원액' in data['상품명'][i]):
            data['중분류'][i] = '가공식품'
            data['소분류'][i] = '전통건강'
            
        elif ('해물철판' in data['상품명'][i]) or ('두부' in data['상품명'][i]) or ('재첩국' in data['상품명'][i]) or ('곤드레나물밥' in data['상품명'][i]) or ('선식' in data['상품명'][i]):
            data['중분류'][i] = '가공식품'
            data['소분류'][i] = '간편/즉석요리'
            
        # 기타
        else:
            data['중분류'][i] = '기타'
            data['소분류'][i] = '기타'

# %% [markdown]
# ## 분류 - 이미용

# %%
# 분류 시작!

for i in range(len(data)):
    if data['상품군'][i] == '이미용':
        
        # 헤어/바디
        if ('샴푸' in data['상품명'][i]) or ('실크테라피' in data['상품명'][i]):
            data['중분류'][i] = '헤어/바디'
            data['소분류'][i] = '헤어케어'
            
        elif ('트리트먼트' in data['상품명'][i]):
            data['중분류'][i] = '헤어/바디'
            data['소분류'][i] = '헤어케어'
            
        elif ('고데롤' in data['상품명'][i]) or ('볼륨브러쉬' in data['상품명'][i]) or ('빗살 뿌리펌' in data['상품명'][i]) or ('셀프뿌리퍼머' in data['상품명'][i]):
            data['중분류'][i] = '헤어/바디'
            data['소분류'][i] = '헤어기기'
            
        elif ('볼륨 스프레이' in data['상품명'][i]):
            data['중분류'][i] = '헤어/바디'
            data['소분류'][i] = '헤어스타일링'
            
        elif ('오일 워시' in data['상품명'][i]) or ('클린샤워' in data['상품명'][i]) or ('풋케어' in data['상품명'][i]):
            data['중분류'][i] = '헤어/바디'
            data['소분류'][i] = '바디케어'
            
            
        
        # 화장품/향수
        elif ('클렌져' in data['상품명'][i]) or ('클렌징패드' in data['상품명'][i]):
            data['중분류'][i] = '화장품/향수'
            data['소분류'][i] = '클렌징'
            
        elif ('남성' in data['상품명'][i]):
            data['중분류'][i] = '화장품/향수'
            data['소분류'][i] = '남성화장품'
            
        elif ('크림' in data['상품명'][i]) or ('세럼' in data['상품명'][i])or ('기초세트' in data['상품명'][i]) or ('링클 리프트' in data['상품명'][i]):
            data['중분류'][i] = '화장품/향수'
            data['소분류'][i] = '기초케어'
            
        elif ('립스틱' in data['상품명'][i]) or ('아이라이너' in data['상품명'][i]) or ('아이스타일러' in data['상품명'][i]):
            data['중분류'][i] = '화장품/향수'
            data['소분류'][i] = '색조'
            
        elif ('선스틱' in data['상품명'][i]) or ('썬스틱' in data['상품명'][i]) or ('선쿠션' in data['상품명'][i]):
            data['중분류'][i] = '화장품/향수'
            data['소분류'][i] = '선케어'
            
        elif ('마스크' in data['상품명'][i]):
            data['중분류'][i] = '화장품/향수'
            data['소분류'][i] = '마스크/팩'
            
        elif ('쿠션' in data['상품명'][i]) or ('팩트' in data['상품명'][i]):
            data['중분류'][i] = '화장품/향수'
            data['소분류'][i] = '베이스'
            
        elif ('네일' in data['상품명'][i]):
            data['중분류'][i] = '화장품/향수'
            data['소분류'][i] = '네일'
            
        elif ('속눈썹세트' in data['상품명'][i]) or ('아이브로우 바' in data['상품명'][i]):
            data['중분류'][i] = '화장품/향수'
            data['소분류'][i] = '뷰티소품'
        
        # 기타
        else:
            data['중분류'][i] = '기타_이미용'
            data['소분류'][i] = '기타_이미용'

# %% [markdown]
# ## 분류 - 가전

# %%
for i in range(len(data)):
    if data['상품군'][i] == '가전':
        # TV/냉장고/세탁기
        if 'TV' in data['상품명'][i]:
            data['중분류'][i] = 'TV/냉장고/세탁기'
            data['소분류'][i] = 'TV'
        elif ('냉장고' in data['상품명'][i]) and ('김치' not in data['상품명'][i]):
            data['중분류'][i] = 'TV/냉장고/세탁기'
            data['소분류'][i] = '냉장고'
        elif '김치냉장고' in data['상품명'][i]:
            data['중분류'][i] = 'TV/냉장고/세탁기'
            data['소분류'][i] = '김치냉장고'
        elif ('세탁기' in data['상품명'][i]) or ('건조기' in data['상품명'][i]) or ('스타일러' in data['상품명'][i]):
            data['중분류'][i] = 'TV/냉장고/세탁기'
            data['소분류'][i] = '세탁/건조/스타일러'
        
        # 계절가전
        elif ('공기청정기' in data['상품명'][i]) or ('공청기' in data['상품명'][i]):
            data['중분류'][i] = '계절가전'
            data['소분류'][i] = '공기청정기'
        elif ('에어컨' in data['상품명'][i]) or (('무풍' in data['상품명'][i]) and ('슬림' in data['상품명'][i])):
            data['중분류'][i] = '계절가전'
            data['소분류'][i] = '에어컨'
            
        # 노트북/PC
        elif '노트북' in data['상품명'][i]:
            data['중분류'][i] = '노트북/PC'
            data['소분류'][i] = '노트북'
            
        # 생활가전
        elif ('청소기' in data['상품명'][i]) or ('로보킹' in data['상품명'][i]):
            data['중분류'][i] = '생활가전'
            data['소분류'][i] = '청소기'

# %% [markdown]
# ## 분류 - 생활용품

# %%
for i in range(len(data)):
    if data['상품군'][i] == '생활용품':
        # 건강/안마/실버
        if '패치' in data['상품명'][i]:
            data['중분류'][i] = '건강/안마/실버'
            data['소분류'][i] = '건강관리용품'
        elif '혈압계' in data['상품명'][i]:
            data['중분류'][i] = '건강/안마/실버'
            data['소분류'][i] = '건강측정용품'
        elif '저출력광선조사기' in data['상품명'][i]:
            data['중분류'][i] = '건강/안마/실버'
            data['소분류'][i] = '물리치료용품'
        elif '안전스틱' in data['상품명'][i]:
            data['중분류'][i] = '건강/안마/실버'
            data['소분류'][i] = '실버/복지용구'
        elif ('목 견인기기' in data['상품명'][i]) or ('마사지기' in data['상품명'][i]) or ('안마' in data['상품명'][i]):
            data['중분류'][i] = '건강/안마/실버'
            data['소분류'][i] = '안마용품'
        elif '바른자세밴드' in data['상품명'][i]:
            data['중분류'][i] = '건강/안마/실버'
            data['소분류'][i] = '의약외품'
            
        # 생활잡화
        elif '공구' in data['상품명'][i]:
            data['중분류'][i] = '생활잡화'
            data['소분류'][i] = '공구/철물/산업재'
        elif '교자상' in data['상품명'][i]:
            data['중분류'][i] = '생활잡화'
            data['소분류'][i] = '교자상/다용도테이블'
        elif ('금고' in data['상품명'][i]) or ('도어락' in data['상품명'][i]):
            data['중분류'][i] = '생활잡화'
            data['소분류'][i] = '보안용품'
        elif '마스크' in data['상품명'][i]:
            data['중분류'][i] = '생활잡화'
            data['소분류'][i] = '안전용품'
            
        # 세제/욕실/위생
        elif '치약' in data['상품명'][i]:
            data['중분류'][i] = '세제/욕실/위생'
            data['소분류'][i] = '구강용품/칫솔'
        elif '면도' in data['상품명'][i]:
            data['중분류'][i] = '세제/욕실/위생'
            data['소분류'][i] = '면도용품/면도기'
        elif '반신욕' in data['상품명'][i]:
            data['중분류'][i] = '세제/욕실/위생'
            data['소분류'][i] = '반신욕용품'
        elif ('화이트업' in data['상품명'][i]) or ('퍼퓸드몽드' in data['상품명'][i]) or ('섬유유연제' in data['상품명'][i]) or ('세제' in data['상품명'][i]):
            data['중분류'][i] = '세제/욕실/위생'
            data['소분류'][i] = '세탁세제/섬유유연제'
        elif '샤워기' in data['상품명'][i]:
            data['중분류'][i] = '세제/욕실/위생'
            data['소분류'][i] = '욕실/목욕용품'
            
        # 세탁/청소용품
        elif ('빨래' in data['상품명'][i]) or ('건조대' in data['상품명'][i]):
            data['중분류'][i] = '세탁/청소용품'
            data['소분류'][i] = '세탁/다림용품'
        elif ('굿터치클리너' in data['상품명'][i]) or ('거름통' in data['상품명'][i]) or ('뚜러킹' in data['상품명'][i]):
            data['중분류'][i] = '세탁/청소용품'
            data['소분류'][i] = '청소용품'
            
        # 수납/정리용품
        elif ('리빙박스' in data['상품명'][i]) or ('스피드랙 베이직' in data['상품명'][i]) or ('선반' in data['상품명'][i]):
            data['중분류'][i] = '수납/정리용품'
            data['소분류'][i] = '수납용품'
        elif ('옷걸이' in data['상품명'][i]) or ('행거' in data['상품명'][i]):
            data['중분류'][i] = '수납/정리용품'
            data['소분류'][i] = '행거'
    
        # 팬시/문구/악기/취미
        elif '예초기' in data['상품명'][i]:
            data['중분류'][i] = '팬시/문구/악기/취미'
            data['소분류'][i] = '원예/조경용품'
            
        # 가방/패션잡화
        elif '선글라스' in data['상품명'][i]:
            data['중분류'][i] = '가방/패션잡화'
            data['소분류'][i] = '패션 ACC'
            
        # 침실가구
        elif ('매트릭스' in data['상품명'][i]) or ('매트리스' in data['상품명'][i]) or ('메모리폼' in data['상품명'][i]):
            data['중분류'][i] = '침실가구'
            data['소분류'][i] = '침대/매트리스'
        elif ('접이식' in data['상품명'][i]) and ('매트' in data['상품명'][i]):
            data['중분류'][i] = '침실가구'
            data['소분류'][i] = '침대/매트리스'
        elif ('라텍스' in data['상품명'][i]) and ('배개' not in data['상품명'][i]):
            data['중분류'][i] = '침실가구'
            data['소분류'][i] = '침대/매트리스'
            
        # 거실가구
        elif '릴렉스 체어' in data['상품명'][i]:
            data['중분류'][i] = '거실가구'
            data['소분류'][i] = '소파'
            
        # 주방가구
        elif ('테이블' in data['상품명'][i]) and ('LP' not in data['상품명'][i]):
            data['중분류'][i] = '주방가구'
            data['소분류'][i] = '식탁'
            
        # 학생/사무용가구
        elif '의자' in data['상품명'][i]:
            data['중분류'][i] = '학생/사무용가구'
            data['소분류'][i] = '의자'
            
        # 침구/커튼/카페트
        elif ('베개' in data['상품명'][i]) or ('배개' in data['상품명'][i]):
            data['중분류'][i] = '침구/커튼/카페트'
            data['소분류'][i] = '베개/커버'
        
        # 홈인테리어
        elif 'LED' in data['상품명'][i]:
            data['중분류'][i] = '홈인테리어'
            data['소분류'][i] = 'LED/전구/조명'
        elif '벽지' in data['상품명'][i]:
            data['중분류'][i] = '홈인테리어'
            data['소분류'][i] = '벽지/시트/스티커'
        elif '디퓨저' in data['상품명'][i]:
            data['중분류'][i] = '홈인테리어'
            data['소분류'][i] = '캔들/디퓨저'
            
        # 계절가전
        elif '공기청정기' in data['상품명'][i]:
            data['중분류'][i] = '계절가전'
            data['소분류'][i] = '공기청정기'
        elif '히터' in data['상품명'][i]:
            data['중분류'][i] = '계절가전'
            data['소분류'][i] = '난방용품'
        elif ('선풍기' in data['상품명'][i]) or ('에어쿨러' in data['상품명'][i]):
            data['중분류'][i] = '계절가전'
            data['소분류'][i] = '선풍기'
        elif ('서큘레이터' in data['상품명'][i]) or ('써큘레이터' in data['상품명'][i]) or ('윈큘레이터' in data['상품명'][i]):
            data['중분류'][i] = '계절가전'
            data['소분류'][i] = '써큘레이터'
        elif '에어컨' in data['상품명'][i]:
            data['중분류'][i] = '계절가전'
            data['소분류'][i] = '에어컨'
        elif ('카페트매트' in data['상품명'][i]) or ('온수매트' in data['상품명'][i]) or ('온열매트' in data['상품명'][i]):
            data['중분류'][i] = '계절가전'
            data['소분류'][i] = '온열매트'
        elif ('물매트' in data['상품명'][i]) or ('쿨잠패드' in data['상품명'][i]):
            data['중분류'][i] = '계절가전'
            data['소분류'][i] = '물매트/냉감패드'
            
        # 블랙박스/자동차
        elif '블랙박스' in data['상품명'][i]:
            data['중분류'][i] = '블랙박스/자동차'
            data['소분류'][i] = '블랙박스'
            
        # 생활가전
        elif '다리미' in data['상품명'][i]:
            data['중분류'][i] = '생활가전'
            data['소분류'][i] = '다리미'
        elif '비데' in data['상품명'][i]:
            data['중분류'][i] = '생활가전'
            data['소분류'][i] = '욕실가전'
        elif '청소기' in data['상품명'][i]:
            data['중분류'][i] = '생활가전'
            data['소분류'][i] = '청소기'
            
        # 영상/음향가전
        elif ('이어폰' in data['상품명'][i]) or ('LP턴테이블' in data['상품명'][i]):
            data['중분류'][i] = '영상/음향가전'
            data['소분류'][i] = '음향가전'
            
        # 등산/캠핑/낚시/자전거
        elif '낚시' in data['상품명'][i]:
            data['중분류'][i] = '등산/캠핑/낚시/자전거'
            data['소분류'][i] = '낚시용품'    
            
        # 자동차용품
        elif '코일카매트' in data['상품명'][i]:
            data['중분류'][i] = '자동차용품'
            data['소분류'][i] = '차량용 시트/매트'
            
        # 헬스/요가/수영/스키
        elif '워킹머신' in data['상품명'][i]:
            data['중분류'][i] = '헬스/요가/수영/스키'
            data['소분류'][i] = '런닝머신/워킹머신'
        elif ('스쿼트머신' in data['상품명'][i]) or ('플래티늄' in data['상품명'][i]):
            data['중분류'][i] = '헬스/요가/수영/스키'
            data['소분류'][i] = '웨이트기구'
            
        # 펫용품
        elif '바리캉' in data['상품명'][i]:
            data['중분류'][i] = '펫용품'
            data['소분류'][i] = '생활용품'

# %% [markdown]
# ## 분류 - 건강기능

# %%
for i in range(len(data)):
    if data['상품군'][i] == '건강기능':
        # 건강기능
        if '루테인' in data['상품명'][i]:
            data['중분류'][i] = '건강기능'
            data['소분류'][i] = '눈건강'
        elif ('모나코사놀' in data['상품명'][i]) or ('오메가' in data['상품명'][i]):
            data['중분류'][i] = '건강기능'
            data['소분류'][i] = '혈행건강'
        elif ('유산균' in data['상품명'][i]) and ('다이어트' not in data['상품명'][i]):
            data['중분류'][i] = '건강기능'
            data['소분류'][i] = '장건강'
        elif '바이오틱스' in data['상품명'][i]:
            data['중분류'][i] = '건강기능'
            data['소분류'][i] = '장건강'
        elif '레모나' in data['상품명'][i]:
            data['중분류'][i] = '건강기능'
            data['소분류'][i] = '면역'
        elif '전립' in data['상품명'][i]:
            data['중분류'][i] = '건강기능'
            data['소분류'][i] = '기타 건강기능'
            
        # 다이어트/이너뷰티
        elif ('레드빈' in data['상품명'][i]) or ('히비스커스' in data['상품명'][i]) or ('다이어트' in data['상품명'][i]):
            data['중분류'][i] = '다이어트/이너뷰티'
            data['소분류'][i] = '다이어트'
        elif ('밀싹 클렌즈' in data['상품명'][i]) or ('석류' in data['상품명'][i]) or ('콜라겐' in data['상품명'][i]):
            data['중분류'][i] = '다이어트/이너뷰티'
            data['소분류'][i] = '피부건강/이너뷰티'
            
        # 전통건강
        elif ('진액' in data['상품명'][i]) or ('해죽순' in data['상품명'][i]) or ('즙' in data['상품명'][i]):
            data['중분류'][i] = '전통건강'
            data['소분류'][i] = '건강즙'
        elif ('생식' in data['상품명'][i]) or ('두유' in data['상품명'][i]):
            data['중분류'][i] = '전통건강'
            data['소분류'][i] = '선식/생식'
        elif '홍합 환' in data['상품명'][i]:
            data['중분류'][i] = '전통건강'
            data['소분류'][i] = '파우더/환'
            
        # 홍삼
        elif '홍삼' in data['상품명'][i]:
            data['중분류'][i] = '홍삼'
            data['소분류'][i] = '홍삼'

# %% [markdown]
# ## 분류 - 잡화

# %%
for i in range(len(data)):
    if data['상품군'][i] == '잡화':
        # 가방/패션잡화
        if '벨트' in data['상품명'][i]:
            data['중분류'][i] = '가방/패션잡화'
            data['소분류'][i] = '벨트'
        elif ('모자' in data['상품명'][i]) or ('머플러' in data['상품명'][i]) or ('선글라스' in data['상품명'][i]) or ('양산' in data['상품명'][i]) or ('케이프' in data['상품명'][i]) or ('스카프' in data['상품명'][i]) or ('장갑' in data['상품명'][i]):
            data['중분류'][i] = '가방/패션잡화'
            data['소분류'][i] = '패션 ACC'
        elif '지갑' in data['상품명'][i]:
            data['중분류'][i] = '가방/패션잡화'
            data['소분류'][i] = '지갑'
        elif ('여행가방' in data['상품명'][i]) or ('캐리어' in data['상품명'][i]):
            data['중분류'][i] = '가방/패션잡화'
            data['소분류'][i] = '여행용가방'
        elif '백팩' in data['상품명'][i]:
            data['중분류'][i] = '가방/패션잡화'
            data['소분류'][i] = '캐주얼가방'
        elif ('백' in data['상품명'][i]) or ('리스틀릿' in data['상품명'][i]) or ('비텔로' in data['상품명'][i]) or ('사첼' in data['상품명'][i]) or ('숄더' in data['상품명'][i]) or ('캐리올' in data['상품명'][i]) or ('스퀘어 크로스' in data['상품명'][i]):
            data['중분류'][i] = '가방/패션잡화'
            data['소분류'][i] = '여성가방/핸드백'
        
        # 쥬얼리/시계
        elif ('시계' in data['상품명'][i]) or ('워치' in data['상품명'][i]):
            data['중분류'][i] = '쥬얼리/시계'
            data['소분류'][i] = '시계'
        elif ('골드바' in data['상품명'][i]) or ('목걸이' in data['상품명'][i]) or ('주얼리' in data['상품명'][i]) or ('팔찌' in data['상품명'][i]) or ('귀걸이' in data['상품명'][i]) or ('반지' in data['상품명'][i]) or ('순금' in data['상품명'][i]):
            data['중분류'][i] = '쥬얼리/시계'
            data['소분류'][i] = '쥬얼리'
        
        # 패션슈즈
        elif ('부츠' in data['상품명'][i]) and ('남성' in data['상품명'][i]):
            data['중분류'][i] = '패션슈즈'
            data['소분류'][i] = '남성화'
        elif ('슬립온' in data['상품명'][i]) and ('남성' in data['상품명'][i]):
            data['중분류'][i] = '패션슈즈'
            data['소분류'][i] = '남성화'
        elif ('캐쥬얼슈즈' in data['상품명'][i]) and ('남성' in data['상품명'][i]):
            data['중분류'][i] = '패션슈즈'
            data['소분류'][i] = '남성화'
        elif ('샌들' in data['상품명'][i]) and ('남성' in data['상품명'][i]):
            data['중분류'][i] = '패션슈즈'
            data['소분류'][i] = '남성화'
        elif ('방한화' in data['상품명'][i]) and ('남성' in data['상품명'][i]):
            data['중분류'][i] = '패션슈즈'
            data['소분류'][i] = '남성화'
        elif '남성화' in data['상품명'][i]:
            data['중분류'][i] = '패션슈즈'
            data['소분류'][i] = '남성화'
        elif ('부츠' in data['상품명'][i]) or ('캐쥬얼슈즈' in data['상품명'][i]) or ('샌들' in data['상품명'][i]) or ('로퍼' in data['상품명'][i]) or ('펌프스' in data['상품명'][i]) or ('방한화' in data['상품명'][i]):
            data['중분류'][i] = '패션슈즈'
            data['소분류'][i] = '여성화'
        elif '스니커즈' in data['상품명'][i]:
            data['중분류'][i] = '패션슈즈'
            data['소분류'][i] = '스니커즈'
        elif ('트레킹화' in data['상품명'][i]) or ('러닝화' in data['상품명'][i]) or ('워킹화' in data['상품명'][i]):
            data['중분류'][i] = '패션슈즈'
            data['소분류'][i] = '트레킹화/러닝화/워킹화'
        elif '슬립온' in data['상품명'][i]:
            data['중분류'][i] = '패션슈즈'
            data['소분류'][i] = '여성화'

# %% [markdown]
# ## 분류 - 가구

# %%
for i in range(len(data)):
    if data['상품군'][i] == '가구':
        # 침실가구
        if '붙박이장' in data['상품명'][i]:
            data['중분류'][i] = '침실가구'
            data['소분류'][i] = '붙박이장'
        elif ('침대' in data['상품명'][i]) or ('베드룸' in data['상품명'][i]) or ('매트리스' in data['상품명'][i]):
            data['중분류'][i] = '침실가구'
            data['소분류'][i] = '침대/매트리스'
        elif ('협탁' in data['상품명'][i]) or ('화장대' in data['상품명'][i]):
            data['중분류'][i] = '침실가구'
            data['소분류'][i] = '화장대/협탁'
            
        # 거실가구
        elif '거실장' in data['상품명'][i]:
            data['중분류'][i] = '거실가구'
            data['소분류'][i] = 'TV거실장'
        elif ('리클라이너' in data['상품명'][i]) or ('소파' in data['상품명'][i]) or ('흙카우치' in data['상품명'][i]) or ('스툴' in data['상품명'][i]):
            data['중분류'][i] = '거실가구'
            data['소분류'][i] = '소파'
        elif '테이블' in data['상품명'][i]:
            data['중분류'][i] = '거실가구'
            data['소분류'][i] = '테이블'
            
        # 수납가구
        elif '서랍장' in data['상품명'][i]:
            data['중분류'][i] = '수납가구'
            data['소분류'][i] = '서랍장'
            
        # 시공/DIY
        elif ('하이바스' in data['상품명'][i]) or ('시공패키지' in data['상품명'][i]):
            data['중분류'][i] = '시공/DIY'
            data['소분류'][i] = '욕실/바스/타일'

# %% [markdown]
# ## 분류 - 침구

# %%
for i in range(len(data)):
    if data['상품군'][i] == '침구':
        # 침구/커튼/카페트
        if ('침구세트' in data['상품명'][i]) or ('침구 풀세트' in data['상품명'][i]):
            data['중분류'][i] = '침구/커튼/카페트'
            data['소분류'][i] = '침구세트'
        elif '커튼' in data['상품명'][i]:
            data['중분류'][i] = '침구/커튼/카페트'
            data['소분류'][i] = '커튼/블라인드'
        elif ('카페트' in data['상품명'][i]) or ('대자리' in data['상품명'][i]):
            data['중분류'][i] = '침구/커튼/카페트'
            data['소분류'][i] = '카페트/러그'

# %%
data.to_csv('data/train_data_02.csv', encoding='utf-8-sig')

# %% [markdown]
# # TEST DATA(6월) 브랜드 칼럼 추가

# %%
data = pd.read_excel('data/2020 빅콘테스트 데이터분석분야-챔피언리그_2020년 6월 판매실적예측데이터(평가데이터).xlsx', header=1)
data
# Out:
#                     방송일시      노출(분)    마더코드    상품코드                   상품명 상품군  \
# 0    2020-06-01 06:20:00  20.000000  100650  201971       잭필드 남성  반팔셔츠 4종  의류
# 1    2020-06-01 06:40:00  20.000000  100650  201971       잭필드 남성  반팔셔츠 4종  의류
# 2    2020-06-01 07:00:00  20.000000  100650  201971       잭필드 남성  반팔셔츠 4종  의류
# 3    2020-06-01 07:20:00  20.000000  100445  202278  쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티  속옷
# 4    2020-06-01 07:40:00  20.000000  100445  202278  쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티  속옷
# ...                  ...        ...     ...     ...                   ...  ..
# 2886 2020-07-01 00:20:00  20.000000  100660  201989       쉴렉스  안마의자 렌탈서비스  무형
# 2887 2020-07-01 00:40:00  20.000000  100660  201989       쉴렉스  안마의자 렌탈서비스  무형
# 2888 2020-07-01 01:00:00  20.000000  100660  201989       쉴렉스  안마의자 렌탈서비스  무형
# 2889 2020-07-01 01:20:00  20.000000  100261  200875        아놀드파마 티셔츠레깅스세트  의류
# 2890 2020-07-01 01:40:00  15.933333  100261  200875        아놀드파마 티셔츠레깅스세트  의류
#
#        판매단가  취급액
# ...

# %%
data['브랜드'] = np.nan

# %% [markdown]
# ## 브랜드 - 의류

# %%
for i in range(len(data)):
    if data['상품군'][i]=='의류':
        data['브랜드'][i] = data['상품명'][i].split()[0]

# %%
data[data['상품군']=='의류']['브랜드'].unique()
# Out:
# array(['잭필드', '코몽트', '마르엘라로사티', '라라쎄', '크리스티나앤코', '마르조', '로질리', '르까프',
#        '예작', '마모트', 'NNF', 'CERINI', '할리마리', '헨리코튼골프', '마르엘라로사티SS와이드팬츠',
#        '예쎄', '젠트웰', '자연감성', '아놀드파마'], dtype=object)

# %%
for i in range(len(data)):
    if data['상품군'][i]=='의류':
        if 'CERINI' in data['상품명'][i]:
            data['브랜드'][i] = 'CERINI by PAT'
        elif '마르엘라로사티' in data['상품명'][i]:
            data['브랜드'][i] = '마르엘라로사티'

# %%
data[data['상품군']=='의류']['브랜드'].unique()
# Out:
# array(['잭필드', '코몽트', '마르엘라로사티', '라라쎄', '크리스티나앤코', '마르조', '로질리', '르까프',
#        '예작', '마모트', 'NNF', 'CERINI by PAT', '할리마리', '헨리코튼골프', '예쎄', '젠트웰',
#        '자연감성', '아놀드파마'], dtype=object)

# %% [markdown]
# ## 브랜드 - 속옷

# %%
for i in range(len(data)):
    if data['상품군'][i]=='속옷':
        data['브랜드'][i] = data['상품명'][i].split()[0]

# %%
data[data['상품군']=='속옷']['브랜드'].unique()
# Out:
# array(['쿠미투니카', '벨레즈온', '아키', '자연감성', '레이프릴', '[일시불]라쉬반', '[무이자]라쉬반',
#        '라쉬반', '실크트리', '몬테밀라노', '오렐리안', '에버라스트', '보디가드', '푸마', '발레리',
#        '프로스펙스', '루시헨느', '헤드', 'LSX'], dtype=object)

# %%
for i in range(len(data)):
    if data['상품군'][i]=='속옷':
        if '라쉬반' in data['상품명'][i]:
            data['브랜드'][i] = '라쉬반'

# %%
data[data['상품군']=='속옷']['브랜드'].unique()
# Out:
# array(['쿠미투니카', '벨레즈온', '아키', '자연감성', '레이프릴', '라쉬반', '실크트리', '몬테밀라노',
#        '오렐리안', '에버라스트', '보디가드', '푸마', '발레리', '프로스펙스', '루시헨느', '헤드', 'LSX'],
#       dtype=object)

# %% [markdown]
# ## 브랜드 - 주방

# %%
for i in range(len(data)):
    if data['상품군'][i] == '주방':
        if '지니어스' in data['상품명'][i]:
            data['브랜드'][i] = '지니어스'
        elif '락앤락' in data['상품명'][i]:
            data['브랜드'][i] = '락앤락'
        elif '램프쿡' in data['상품명'][i]:
            data['브랜드'][i] = '램프쿡'
        elif '린나이' in data['상품명'][i]:
            data['브랜드'][i] = '린나이'
        elif '매직쉐프' in data['상품명'][i]:
            data['브랜드'][i] = '매직쉐프'
        elif '올리고' in data['상품명'][i]:
            data['브랜드'][i] = '올리고'
        elif 'am' in data['상품명'][i]:
            data['브랜드'][i] = 'am마카롱'
        elif '쿠첸' in data['상품명'][i]:
            data['브랜드'][i] = '쿠첸'
        elif '에버홈' in data['상품명'][i]:
            data['브랜드'][i] = '에버홈'
        elif '에지리' in data['상품명'][i]:
            data['브랜드'][i] = '에지리'
        elif '제오닉' in data['상품명'][i]:
            data['브랜드'][i] = '제오닉'
        elif '쿠진' in data['상품명'][i]:
            data['브랜드'][i] = '쿠진'
        elif '파뷔에' in data['상품명'][i]:
            data['브랜드'][i] = '파뷔에'
        elif '프로피쿡' in data['상품명'][i]:
            data['브랜드'][i] = '프로피쿡'
        elif '한일' in data['상품명'][i]:
            data['브랜드'][i] = '한일'
        elif '쿠쿠' in data['상품명'][i]:
            data['브랜드'][i] = '쿠쿠'
        elif 'PN' in data['상품명'][i]:
            data['브랜드'][i] = '풍년'
        else:
            data['브랜드'][i] = '기타_주방'

# %% [markdown]
# ## 브랜드 - 농수축

# %%
for i in range(len(data)):
    if data['상품군'][i]=='농수축':
        if '이봉원' in data['상품명'][i]:
            data['브랜드'][i] = '이봉원'
        elif '농협' in data['상품명'][i]:
            data['브랜드'][i] = '농협'
        elif '우리바다' in data['상품명'][i]:
            data['브랜드'][i] = '우리바다'
        elif '안동' in data['상품명'][i]:
            data['브랜드'][i] = '안동'
        elif '삼립' in data['상품명'][i]:
            data['브랜드'][i] = '삼립'
        elif '하림' in data['상품명'][i]:
            data['브랜드'][i] = '하림'
        elif '바다먹자' in data['상품명'][i]:
            data['브랜드'][i] = '바다먹자'
        elif '피시원' in data['상품명'][i]:
            data['브랜드'][i] = '피시원'
        elif '천연담아' in data['상품명'][i]:
            data['브랜드'][i] = '천연담아'
        elif '청정수산' in data['상품명'][i]:
            data['브랜드'][i] = '청정수산'
        elif '영산포' in data['상품명'][i]:
            data['브랜드'][i] = '영산포'
        elif '소들녘' in data['상품명'][i]:
            data['브랜드'][i] = '소들녘'
        elif '팽현숙' in data['상품명'][i]:
            data['브랜드'][i] = '팽현숙'
        elif '천수봉' in data['상품명'][i]:
            data['브랜드'][i] = '천수봉'        
        elif '수협' in data['상품명'][i]:
            data['브랜드'][i] = '수협'        
        elif '제주바다' in data['상품명'][i]:
            data['브랜드'][i] = '제주바다'
        elif '곡물그대로' in data['상품명'][i]:
            data['브랜드'][i] = '곡물그대로' 
        elif '장보고' in data['상품명'][i]:
            data['브랜드'][i] = '장보고'       
        elif '양구' in data['상품명'][i]:
            data['브랜드'][i] ='양구'       
        elif '카라카라' in data['상품명'][i]:
            data['브랜드'][i] = '카라카라'       
        elif '김정문' in data['상품명'][i]:
            data['브랜드'][i] = '김정문'
        elif '이만기' in data['상품명'][i]:
            data['브랜드'][i] = '이만기'    
        elif '본죽' in data['상품명'][i]:
            data['브랜드'][i] = '본죽'
        elif '영광' in data['상품명'][i]:
            data['브랜드'][i] = '영광'
        elif '유귀열' in data['상품명'][i]:
            data['브랜드'][i] ='유귀열'
        elif '최인선' in data['상품명'][i]:
            data['브랜드'][i] = '최인선'
        elif '바다원' in data['상품명'][i]:
            data['브랜드'][i] = '바다원'       
        elif 'LA갈비' in data['상품명'][i]:
            data['브랜드'][i] = 'LA갈비'      
        elif '맛있는 제주' in data['상품명'][i]:
            data['브랜드'][i] = '맛있는 제주'       
        elif '전철우' in data['상품명'][i]:
            data['브랜드'][i] = '전철우'       
        elif '이경제' in data['상품명'][i]:
            data['브랜드'][i] = '이경제'       
        elif '하동' in data['상품명'][i]:
            data['브랜드'][i] = '하동'        
        elif '창녕' in data['상품명'][i]:
            data['브랜드'][i] = '창녕'         
        elif '깐깐송도순' in data['상품명'][i]:
            data['브랜드'][i] = '깐깐송도순' 
        elif '임성근' in data['상품명'][i]:
            data['브랜드'][i] = '임성근'         
        elif '현대어찬' in data['상품명'][i]:
            data['브랜드'][i] = '현대어찬'         
        elif '예천청결' in data['상품명'][i]:
            data['브랜드'][i] = '예천청결'         
        elif '하늘내린' in data['상품명'][i]:
            data['브랜드'][i] = '하늘내린'         
        elif '김선영' in data['상품명'][i]:
            data['브랜드'][i] = '김선영'         
        elif '김규흔' in data['상품명'][i]:
            data['브랜드'][i] = '김규흔'       
        elif '신세대' in data['상품명'][i]:
            data['브랜드'][i] = '신세대'         
        elif '목우촌' in data['상품명'][i]:
            data['브랜드'][i] = '목우촌'         
        elif '김정배' in data['상품명'][i]:
            data['브랜드'][i] = '김정배'         
        elif '이보은' in data['상품명'][i]:
            data['브랜드'][i] = '이보은'         
        elif '슬로푸드' in data['상품명'][i]:
            data['브랜드'][i] = '슬로푸드'         
        elif '오세득' in data['상품명'][i]:
            data['브랜드'][i] = '오세득'        
        elif '강레오' in data['상품명'][i]:
            data['브랜드'][i] = '강레오'            
        elif '산머루농원 ' in data['상품명'][i]:
            data['브랜드'][i] = '산머루농원'
        elif '식탁앤김 ' in data['상품명'][i]:
            data['브랜드'][i] = '식탁앤김'
        elif '조방할매 ' in data['상품명'][i]:
            data['브랜드'][i] = '조방할매'
        elif '옛날 그 쥐포 ' in data['상품명'][i]:
            data['브랜드'][i] = '옛날 그 쥐포'
        elif '참바다 ' in data['상품명'][i]:
            data['브랜드'][i] = '참바다'
        elif '잔다리 ' in data['상품명'][i]:
            data['브랜드'][i] = '참바다'
        else:
            data['브랜드'][i] = '기타_농수축브랜드'

# %% [markdown]
# ## 브랜드 - 이미용

# %%
for i in range(len(data)):
    if data['상품군'][i]=='이미용':
        data['브랜드'][i] = data['상품명'][i].split()[0]

# %%
data[(data['상품군'] == '이미용') & (data['브랜드'].notnull())].shape   # 167개 확인
# Out:
# (167, 9)

# %%
data[data['상품군']=='이미용']['브랜드'].unique()
# Out:
# array(['바비리스', '에이유플러스', '더블모', '실크테라피', '엘렌실라', '[VONIN]보닌', '셀럽by재클린',
#        '족선생', '블링썸', '참존', '끌레드벨', '프리미엄', '프리지아', 'NEW', '비버리힐스폴로클럽',
#        '래쉬톡', '제니하우스', '엘렌실라&코즈미'], dtype=object)

# %%
for i in range(len(data)):
    if data['상품군'][i]=='이미용':
        if '[VONIN]보닌' in data['브랜드'][i]:
            data['브랜드'][i] = '보닌'
        elif 'NEW' in data['브랜드'][i]:
            data['브랜드'][i] = '바바코코'
        elif '프리지아' in data['브랜드'][i]:
            data['브랜드'][i] = '프리지아안단티노'
        elif '프리미엄' in data['브랜드'][i]:
            data['브랜드'][i] = '클린샤워'

# %%
data[data['상품군']=='이미용']['브랜드'].unique()
# Out:
# array(['바비리스', '에이유플러스', '더블모', '실크테라피', '엘렌실라', '보닌', '셀럽by재클린', '족선생',
#        '블링썸', '참존', '끌레드벨', '클린샤워', '프리지아안단티노', '바바코코', '비버리힐스폴로클럽',
#        '래쉬톡', '제니하우스', '엘렌실라&코즈미'], dtype=object)

# %% [markdown]
# ## 브랜드 - 가전

# %%
for i in range(len(data)):
    if data['상품군'][i]=='가전':
        if '삼성' in data['상품명'][i]:
            data['브랜드'][i] = '삼성'
        elif 'LG' in data['상품명'][i]:
            data['브랜드'][i] = 'LG'
        elif '대우' in data['상품명'][i]:
            data['브랜드'][i] = '대우전자'
        elif '캐리어' in data['상품명'][i] and '김치' not in data['상품명'][i]:
            data['브랜드'][i] = '캐리어'
        elif '딤채' in data['상품명'][i]:
            data['브랜드'][i] = '딤채'
        else:
            data['브랜드'][i] = '기타_가전브랜드'

# %%
data[(data['상품군'] == '이미용') & (data['브랜드'].isnull())]
# Out:
# Empty DataFrame
# Columns: [방송일시, 노출(분), 마더코드, 상품코드, 상품명, 상품군, 판매단가, 취급액, 브랜드]
# Index: []

# %% [markdown]
# ## 브랜드 - 생활용품

# %%
# 생활용품 - 브랜드

for i in range(len(data)):
    if data['상품군'][i]=='생활용품':
        if '벨라홈' in data['상품명'][i]:
            data['브랜드'][i] = '벨라홈'
        elif '노비타' in data['상품명'][i]:
            data['브랜드'][i] = '노비타'
        elif '코이모' in data['상품명'][i]:
            data['브랜드'][i] = '코이모'
        elif '스위스밀리터리' in data['상품명'][i]:
            data['브랜드'][i] = '스위스밀리터리'
        elif '크린조이' in data['상품명'][i]:
            data['브랜드'][i] = '크린조이'
        elif '세렌셉템버' in data['상품명'][i]:
            data['브랜드'][i] = '세렌셉템버'
        elif '까사마루' in data['상품명'][i]:
            data['브랜드'][i] = '까사마루'
        elif '바로바로' in data['상품명'][i]:
            data['브랜드'][i] = '바로바로'
        elif '올바로' in data['상품명'][i]:
            data['브랜드'][i] = '올바로'
        elif 'LG생활건강' in data['상품명'][i]:
            data['브랜드'][i] = 'LG생활건강'
        elif '굿프렌드' in data['상품명'][i]:
            data['브랜드'][i] = '굿프렌드'
        elif '스피드랙' in data['상품명'][i]:
            data['브랜드'][i] = '스피드랙'
        elif '모리츠' in data['상품명'][i]:
            data['브랜드'][i] = '모리츠'
        elif '한일' in data['상품명'][i]:
            data['브랜드'][i] = '한일'
        elif '디비노' in data['상품명'][i]:
            data['브랜드'][i] = '디비노'
        elif '이지스' in data['상품명'][i]:
            data['브랜드'][i] = '이지스'
        elif '도루코' in data['상품명'][i]:
            data['브랜드'][i] = '도루코'
        elif '노송가구' in data['상품명'][i]:
            data['브랜드'][i] = '노송가구'
        elif '퀸메이드' in data['상품명'][i]:
            data['브랜드'][i] = '퀸메이드'
        elif '블루콤' in data['상품명'][i]:
            data['브랜드'][i] = '블루콤'
        elif '캐치온' in data['상품명'][i]:
            data['브랜드'][i] = '캐치온'
        elif '킹스스파' in data['상품명'][i]:
            data['브랜드'][i] = '킹스스파'
        elif '바두기' in data['상품명'][i]:
            data['브랜드'][i] = '바두기'
        elif '일월' in data['상품명'][i]:
            data['브랜드'][i] = '일월'
        elif '트라이' in data['상품명'][i]:
            data['브랜드'][i] = '트라이'
        elif '발렌티노루디' in data['상품명'][i]:
            data['브랜드'][i] = '발렌티노루디'
        elif '사운드룩' in data['상품명'][i]:
            data['브랜드'][i] = '사운드룩'
        elif '레스트업' in data['상품명'][i]:
            data['브랜드'][i] = '레스트업'
        elif '한솔' in data['상품명'][i]:
            data['브랜드'][i] = '한솔'
        elif '파로마' in data['상품명'][i]:
            data['브랜드'][i] = '파로마'
        elif '테팔' in data['상품명'][i]:
            data['브랜드'][i] = '테팔'
        elif '코지마' in data['상품명'][i]:
            data['브랜드'][i] = '코지마'
        elif '엑사이더' in data['상품명'][i]:
            data['브랜드'][i] = '엑사이더'
        elif '스칸디나비아' in data['상품명'][i]:
            data['브랜드'][i] = '스칸디나비아'
        elif 'KF94' in data['상품명'][i]:
            data['브랜드'][i] = 'KF94'
        elif '선일' in data['상품명'][i]:
            data['브랜드'][i] = '선일'
        elif '메디쉴드' in data['상품명'][i]:
            data['브랜드'][i] = '메디쉴드'
        elif '선일' in data['상품명'][i]:
            data['브랜드'][i] = '선일'
        elif '김병만' in data['상품명'][i]:
            data['브랜드'][i] = '김병만'
        elif '숀리' in data['상품명'][i]:
            data['브랜드'][i] = '숀리'
        elif '메디컬드림' in data['상품명'][i]:
            data['브랜드'][i] = '메디컬드림'
        elif '거미손' in data['상품명'][i]:
            data['브랜드'][i] = '거미손'
        elif '바로톡' in data['상품명'][i]:
            data['브랜드'][i] = '바로톡'
        elif '대웅' in data['상품명'][i]:
            data['브랜드'][i] = '대웅'
        elif '뚜러킹' in data['상품명'][i]:
            data['브랜드'][i] = '뚜러킹'
        elif '자미코코' in data['상품명'][i]:
            data['브랜드'][i] = '자미코코'
        elif '타이거' in data['상품명'][i]:
            data['브랜드'][i] = '타이거'
        elif '브람스' in data['상품명'][i]:
            data['브랜드'][i] = '브람스'
        elif '니봇' in data['상품명'][i]:
            data['브랜드'][i] = '니봇'
        elif '중외신약' in data['상품명'][i]:
            data['브랜드'][i] = '중외신약'
        elif '밀레' in data['상품명'][i]:
            data['브랜드'][i] = '밀레'
        elif '스팀큐' in data['상품명'][i]:
            data['브랜드'][i] = '스팀큐'
        elif '김병지' in data['상품명'][i]:
            data['브랜드'][i] = '김병지'
        elif '센스하우스' in data['상품명'][i]:
            data['브랜드'][i] = '센스하우스'
        elif '페르소나' in data['상품명'][i]:
            data['브랜드'][i] = '페르소나'
        elif '센티멘탈' in data['상품명'][i]:
            data['브랜드'][i] = '센티멘탈'
        elif '센스톰' in data['상품명'][i]:
            data['브랜드'][i] = '센스톰'
        elif '보국' in data['상품명'][i]:
            data['브랜드'][i] = '보국'
        elif '따스림' in data['상품명'][i]:
            data['브랜드'][i] = '따스림'
        elif '자미코코' in data['상품명'][i]:
            data['브랜드'][i] = '자미코코'
        elif '루미테라피' in data['상품명'][i]:
            data['브랜드'][i] = '루미테라피'
        elif '월시스' in data['상품명'][i]:
            data['브랜드'][i] = '월시스'
        elif '히팅맘' in data['상품명'][i]:
            data['브랜드'][i] = '히팅맘'
        elif '수련' in data['상품명'][i]:
            data['브랜드'][i] = '수련'
        elif '밸런스파워' in data['상품명'][i]:
            data['브랜드'][i] = '밸런스파워'
        elif '3D' in data['상품명'][i]:
            data['브랜드'][i] = '3D매쉬'
        elif '파워스윙' in data['상품명'][i]:
            data['브랜드'][i] = '파워스윙'
        elif 'OK' in data['상품명'][i]:
            data['브랜드'][i] = 'OK'
        elif '프리모' in data['상품명'][i]:
            data['브랜드'][i] = '프리모'
        elif '신일' in data['상품명'][i]:
            data['브랜드'][i] = '신일'
        elif '닥터웰' in data['상품명'][i]:
            data['브랜드'][i] = '닥터웰'
        elif '벨리슬립' in data['상품명'][i]:
            data['브랜드'][i] = '벨리슬립'
        elif '르젠' in data['상품명'][i]:
            data['브랜드'][i] = '르젠'
        elif '에레키반' in data['상품명'][i]:
            data['브랜드'][i] = '에레키반'
        elif '벤트리' in data['상품명'][i]:
            data['브랜드'][i] = '벤트리'
        elif '공간아트' in data['상품명'][i]:
            data['브랜드'][i] = '공간아트'
        elif '에브리빙' in data['상품명'][i]:
            data['브랜드'][i] = '에브리빙'
        elif '단순생활' in data['상품명'][i]:
            data['브랜드'][i] = '단순생활'
        elif '아룬싸왓' in data['상품명'][i]:
            data['브랜드'][i] = '아룬싸왓'

# %% [markdown]
# ## 브랜드 - 건강기능

# %%
for i in range(len(data)):
    if data['상품군'][i] == '건강기능':
        if '뉴트리원' in data['상품명'][i]:
            data['브랜드'][i] = '뉴트리원'
        elif '종근당' in data['상품명'][i]:
            data['브랜드'][i] = '종근당'
        else:
            data['브랜드'][i] = '기타_건강기능'

# %% [markdown]
# ## 브랜드 - 잡화

# %%
brands=[
'가이거',
'소노비',
'톰포드',
'W클라우드',
'레비노블',
'페리엘리스',
'페라가모',
'생로랑',
'메디아글램',
'안드레아바나',
'루이띠에',
'플로쥬',
'DIOR',
'RYN',
'로베르타',
'엘리자베스아덴',
'갈란테',
'골드파일',
'구찌',
'도스문도스',
'레노마',
'레코바',
'마스케라',
'마이클코어스',
'메이듀',
'썸덱스',
'바치',
'버버리',
'삭루츠',
'생쥴랑',
'세인트스코트',
'스프리스',
'시스마르스',
'아가타',
'아르테사노',
'알비에로',
'에버라스트',
'에트로',
'에펨',
'엘르',
'오델로',
'월드컵',
'제옥스',
'칼리베이직',
'코치',
'트레스패스',
'프라다',
'AAA',
'AAD',
'기라로쉬'
]

# %%
for i in range(len(data)):
    if data['상품군'][i]=='잡화':
        for brand in brands:
            if brand in data['상품명'][i]:
                data['브랜드'][i]=brand
        if '생줄랑' in data['상품명'][i]:
            data['브랜드'][i]='생쥴랑'

# %% [markdown]
# ## 브랜드 - 가구

# %%
for i in range(len(data)):
    if data['상품군'][i]=='가구':
        data['브랜드'][i] = data['상품명'][i].split()[0]

# %%
data[(data['상품군'] == '가구') & (data['브랜드'].notnull())].shape   # 159개 확인
# Out:
# (159, 9)

# %%
data[data['상품군']=='가구']['브랜드'].unique()
# Out:
# array(['보루네오', '4인용', '6인용', '3인용', '(단품)우아미리프트업테이블', '(단품)우아미오토만스툴',
#        '(일)[보루네오]', '(무)[보루네오]', '(퀸)', '(싱글)', '행복돌침대'], dtype=object)

# %%
for i in range(len(data)):
    if data['상품군'][i]=='가구':
        if '4인용' in data['브랜드'][i]:
            data['브랜드'][i] = '우아미'
        elif '6인용' in data['브랜드'][i]:
            data['브랜드'][i] = '우아미'
        elif '3인용' in data['브랜드'][i]:
            data['브랜드'][i] = '우아미'
        elif '(단품)우아미리프트업테이블' in data['브랜드'][i]:
            data['브랜드'][i] = '우아미'
        elif '(단품)우아미오토만스툴' in data['브랜드'][i]:
            data['브랜드'][i] = '우아미'
        elif '(일)[보루네오]' in data['브랜드'][i]:
            data['브랜드'][i] = '보루네오'
        elif '(무)[보루네오]' in data['브랜드'][i]:
            data['브랜드'][i] = '보루네오'
        elif '(퀸)' in data['브랜드'][i]:
            data['브랜드'][i] = '행복돌침대'
        elif '(싱글)' in data['브랜드'][i]:
            data['브랜드'][i] = '행복돌침대'

# %%
data[data['상품군']=='가구']['브랜드'].unique()
# Out:
# array(['보루네오', '우아미', '행복돌침대'], dtype=object)

# %%
data[(data['상품군'] == '가구') & (data['브랜드'].isnull())]
# Out:
# Empty DataFrame
# Columns: [방송일시, 노출(분), 마더코드, 상품코드, 상품명, 상품군, 판매단가, 취급액, 브랜드]
# Index: []

# %% [markdown]
# ## 브랜드 - 침구

# %%
# 침구 - 브랜드

for i in range(len(data)):
    if data['상품군'][i]=='침구':
        if '보몽드' in data['상품명'][i]:
            data['브랜드'][i] = '보몽드'
        elif '한샘' in data['상품명'][i]:
            data['브랜드'][i] = '한샘'
        elif '리앤코리아' in data['상품명'][i]:
            data['브랜드'][i] = '리앤'
        elif '효재' in data['상품명'][i]:
            data['브랜드'][i] = '효재'
        elif '안지' in data['상품명'][i]:
            data['브랜드'][i] = '안지'
        elif '한빛' in data['상품명'][i]:
            data['브랜드'][i] = '한빛'
        elif '리앤' in data['상품명'][i]:
            data['브랜드'][i] = '리앤'
        elif '지나송' in data['상품명'][i]:
            data['브랜드'][i] = '지나송'
        elif '한스데코' in data['상품명'][i]:
            data['브랜드'][i] = '한스데코'

# %%
data.head(30)
# Out:
#                   방송일시  노출(분)    마더코드    상품코드                           상품명  \
# 0  2020-06-01 06:20:00   20.0  100650  201971               잭필드 남성  반팔셔츠 4종
# 1  2020-06-01 06:40:00   20.0  100650  201971               잭필드 남성  반팔셔츠 4종
# 2  2020-06-01 07:00:00   20.0  100650  201971               잭필드 남성  반팔셔츠 4종
# 3  2020-06-01 07:20:00   20.0  100445  202278          쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티
# 4  2020-06-01 07:40:00   20.0  100445  202278          쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티
# 5  2020-06-01 08:00:00   20.0  100445  202278          쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티
# 6  2020-06-01 08:20:00   20.0  100381  201247               바비리스 퍼펙트 볼륨스타일러
# 7  2020-06-01 08:40:00   20.0  100381  201247               바비리스 퍼펙트 볼륨스타일러
# 8  2020-06-01 09:00:00   20.0  100381  201247               바비리스 퍼펙트 볼륨스타일러
# 9  2020-06-01 09:20:00   20.0  100638  201956                    램프쿡 자동회전냄비
# 10 2020-06-01 09:40:00   20.0  100638  201956                    램프쿡 자동회전냄비
# ...

# %% [markdown]
# # TEST DATA(6월) 중분류, 소분류 칼럼 추가

# %%
data['중분류'] = np.nan
data['소분류'] = np.nan
data.head()
# Out:
#                  방송일시  노출(분)    마더코드    상품코드                   상품명 상품군   판매단가  \
# 0 2020-06-01 06:20:00   20.0  100650  201971       잭필드 남성  반팔셔츠 4종  의류  59800
# 1 2020-06-01 06:40:00   20.0  100650  201971       잭필드 남성  반팔셔츠 4종  의류  59800
# 2 2020-06-01 07:00:00   20.0  100650  201971       잭필드 남성  반팔셔츠 4종  의류  59800
# 3 2020-06-01 07:20:00   20.0  100445  202278  쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티  속옷  69900
# 4 2020-06-01 07:40:00   20.0  100445  202278  쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티  속옷  69900
#
#    취급액    브랜드  중분류  소분류
# 0  NaN    잭필드  NaN  NaN
# 1  NaN    잭필드  NaN  NaN
# 2  NaN    잭필드  NaN  NaN
# 3  NaN  쿠미투니카  NaN  NaN
# 4  NaN  쿠미투니카  NaN  NaN

# %% [markdown]
# ## 분류 - 의류

# %%
# 중분류 시작
for i in range(len(data)):
    if data['상품군'][i] == '의류':
        if ('남녀' in data['상품명'][i]):
            data['중분류'][i] = '캐주얼/유니섹스'
        
        elif '남성' in data['상품명'][i]:
            data['중분류'][i] = '남성의류'
            
        elif '여성' in data['상품명'][i]:
            data['중분류'][i] = '여성의류'
            
        elif ('원피스' in data['상품명'][i]) or ('쉬폰' in data['상품명'][i]) or ('레깅스' in data['상품명'][i]) or ('앙상블' in data['상품명'][i]):
            data['중분류'][i] = '여성의류'
        
        elif ('마르엘라로사티' in data['상품명'][i]) or ('NNF' in data['상품명'][i]) or ('마모트' in data['상품명'][i]):
            data['중분류'][i] = '여성의류'
        
#         elif ('성인' in main['상품명'][i]):
#             main['중분류'][i] = '캐주얼/유니섹스'
        
        elif '코몽트' in data['상품명'][i]:
            data['중분류'][i] = '남성의류'
        
        else:
            data['중분류'][i] = '기타_의류'
        

for i in range(len(data)):
    if data['중분류'][i] == '여성의류':
        if ('밍크' in data['상품명'][i]) or ('양가죽' in data['상품명'][i]) or ('모피' in data['상품명'][i]) or ('무스탕' in data['상품명'][i]):
            data['소분류'][i] = '가죽/모피/무스탕'
            
        elif ('자켓' in data['상품명'][i]) or ('재킷' in data['상품명'][i]) or ('점퍼' in data['상품명'][i]) or ('코트' in data['상품명'][i]) or ('패딩' in data['상품명'][i]) or ('다운' in data['상품명'][i]):
            data['소분류'][i] = '자켓/점퍼/코트'
        
        elif ('니트' in data['상품명'][i]) or ('가디건' in data['상품명'][i]) or ('베스트' in data['상품명'][i]) or ('스웨터' in data['상품명'][i]) or ('앙상블' in data['상품명'][i]):
            data['소분류'][i] = '니트/가디건'
            
        elif ('블라우스' in data['상품명'][i]) or ('셔츠' in data['상품명'][i]) or ('쉬폰' in data['상품명'][i]):
            data['소분류'][i] = '블라우스/셔츠'
        
        elif ('스커트' in data['상품명'][i]):
            data['소분류'] = '스커트'
            
        elif ('원피스' in data['상품명'][i]):
            data['소분류'][i] = '원피스'
        
        elif ('티셔츠' in data['상품명'][i]) or ('터틀넥' in data['상품명'][i]) or ('맨투맨' in data['상품명'][i]) or ('기모티' in data['상품명'][i]) or ('모크넥' in data['상품명'][i]):
            data['소분류'][i] = '티셔츠'
            
        elif ('팬츠' in data['상품명'][i]) or ('데님' in data['상품명'][i]):
            data['소분류'][i] = '팬츠/데님'
        
        elif ('액티비티' in data['상품명'][i]) or ('트레이닝' in data['상품명'][i]) or ('트랙수트' in data['상품명'][i]) or ('라운지웨어' in data['상품명'][i]) or ('마모트' in data['상품명'][i]) or ('EXR' in data['상품명'][i]) or ('이지웨어' in data['상품명'][i]):
            data['소분류'][i] = '트레이닝'
            
        elif ('풀코디' in data['상품명'][i]) or ('세트' in data['상품명'][i]):
            data['소분류'][i] = '세트'
        else:
            data['소분류'][i] = '기타_여성의류'
            

for i in range(len(data)):
    if data['중분류'][i] == '남성의류':
        if ('가디건' in data['상품명'][i]):
            data['소분류'][i] = '가디건'
        
        elif ('자켓' in data['상품명'][i]) or ('재킷' in data['상품명'][i]) or ('점퍼' in data['상품명'][i]) or ('코트' in data['상품명'][i]) or ('패딩' in data['상품명'][i]) or ('다운' in data['상품명'][i]):
            data['소분류'][i] = '자켓/점퍼/코트'
        
        elif ('니트' in data['상품명'][i]) or ('스웨터' in data['상품명'][i]):
            data['소분류'][i] = '니트/가디건'
            
        elif ('팬츠' in data['상품명'][i]) or ('데님' in data['상품명'][i]) or ('반바지' in data['상품명'][i]):
            data['소분류'][i] = '팬츠/데님'
            
        elif ('티셔츠' in data['상품명'][i]) or ('터틀넥' in data['상품명'][i]) or ('맨투맨' in data['상품명'][i]) or ('기모티' in data['상품명'][i]) or ('모크넥' in data['상품명'][i]):
            data['소분류'][i] = '티셔츠'
            
        elif('셔츠' in data['상품명'][i]) or ('남방' in data['상품명'][i]):
            data['소분류'][i] = '셔츠/남방'
            
        elif ('베스트' in data['상품명'][i]) or ('조끼' in data['상품명'][i]):
            data['소분류'][i] = '베스트/조끼'
            
        
        

            
        
        
        elif ('액티비티' in data['상품명'][i]) or ('트레이닝' in data['상품명'][i]) or ('트랙수트' in data['상품명'][i]) or ('라운지웨어' in data['상품명'][i]) or ('마모트' in data['상품명'][i]) or ('EXR' in data['상품명'][i]) or ('이지웨어' in data['상품명'][i]):
            data['소분류'][i] = '트레이닝'
            
        elif ('풀코디' in data['상품명'][i]) or ('세트' in data['상품명'][i]):
            data['소분류'][i] = '세트'
        else:
            data['소분류'][i] = '기타_남성의류'

# %% [markdown]
# ## 분류 - 속옷

# %%
# 분류 시작
# 중분류 나누기
for i in range(len(data)):
    if data['상품군'][i] == '속옷':
        if ('드로즈' in data['상품명'][i]):
            data['중분류'][i] = '남성속옷'
            data['소분류'][i] = '드로즈'
        
        elif ('트렁크' in data['상품명'][i]):
            data['중분류'][i] = '남성속옷'
            data['소분류'][i] = '트렁크팬티'
            
        # 남성 언더셔츠
        elif ('언더셔츠' in data['상품명'][i]) or ('언더탑' in data['상품명'][i]):
            data['중분류'][i] = '남성속옷'
            data['소분류'][i] = '언더셔츠'
            
        # 남성 런닝
        elif ('런닝' in data['상품명'][i]):
            data['중분류'][i] = '남성속옷'
            data['소분류'][i] = '런닝/내의'
            
        # 여성 팬티
        elif ('팬티' in data['상품명'][i]):
            data['중분류'][i] = '여성속옷'
            data['소분류'][i] = '팬티'
            
        elif ('란쥬' in data['상품명'][i]) or ('쉐이퍼' in data['상품명'][i]):
            data['중분류'][i] = '여성속옷'
            data['소분류'][i] = '란쥬/쉐이퍼'
        
        # 여성런닝
        elif ('보정' in data['상품명'][i]) & ('런닝' in data['상품명'][i]):
            data['중분류'][i] = '여성속옷'
            data['소분류'][i] = '런닝/내의'
            
        # 여성 브래지어
        elif ('브라' in data['상품명'][i]):
            data['중분류'][i] = '여성속옷'
            data['소분류'][i] = '브래지어'
        
        # 여성 이지웨어/잠옷    
        elif ('원피스' in data['상품명'][i]) or ('이지웨어' in data['상품명'][i]):
            data['중분류'][i] = '여성속옷'
            data['소분류'][i] = '이지웨어/잠옷'
            
        
        else:
            data['중분류'][i] = '기타_속옷'
            data['소분류'][i] = '기타_속옷_소'

# %% [markdown]
# ## 분류 - 주방

# %%
# 분류 시작
# 주방 중, 소분류 나누기
for i in range(len(data)):
    if data['상품군'][i] == '주방':
        
        #  주방가전
        if ('전기밥솥' in data['상품명'][i]) or ('압력밥솥' in data['상품명'][i]):
            data['중분류'][i] = '주방가전'
            data['소분류'][i] = '전기밥솥'
        
        elif ('가스레인지' in data['상품명'][i]) or ('가스와이드그릴레인지' in data['상품명'][i]):
            data['중분류'][i] = '주방가전'
            data['소분류'][i] = '가스/전기레인지'
            
        elif ('전자레인지' in data['상품명'][i]):
            data['중분류'][i] = '주방가전'
            data['소분류'][i] = '전자레인지/오븐'
        
        elif ('블렌더' in data['상품명'][i]) or ('믹서' in data['상품명'][i]):
            data['중분류'][i] = '주방가전'
            data['소분류'][i] = '믹서/분쇄기'
            
        elif ('건조기' in data['상품명'][i]):
            data['중분류'][i] = '주방가전'
            data['소분류'][i] = '식기세척기/건조기'
            
        elif ('에어프라이어' in data['상품명'][i]):
            data['중분류'][i] = '주방가전'
            data['소분류'][i] = '조리/가열기기'
        
        # 주방용품/식기
        elif ('프라이팬' in data['상품명'][i]) or ('후라이팬' in data['상품명'][i]):
            data['중분류'][i] = '주방용품/식기'
            data['소분류'][i] = '프라이팬'
            
        elif ('압력솥' in data['상품명'][i]) or ('냄비' in data['상품명'][i]):
            data['중분류'][i] = '주방용품/식기'
            data['소분류'][i] = '냄비/압력솥'
            
        elif ('텀블러' in data['상품명'][i]):
            data['중분류'][i] = '주방용품/식기'
            data['소분류'][i] = '보온/보냉/야외용품'
            
        elif ('밀폐용기' in data['상품명'][i]):
            data['중분류'][i] = '주방용품/식기'
            data['소분류'][i] = '물병/보관/밀폐용기'
            
        elif ('채칼' in data['상품명'][i]) or ('다지기' in data['상품명'][i]):
            data['중분류'][i] = '주방용품/식기'
            data['소분류'][i] = '조리도구'
        
        else:
            data['중분류'][i] = '기타_주방'
            data['소분류'][i] = '기타_주방_소'

# %% [markdown]
# ## 분류 - 농수축

# %%
# 분류 시작


for i in range(len(data)):
    if data['상품군'][i] == '농수축':
        
        # 농산
        if ('사과' in data['상품명'][i]) or ('키위' in data['상품명'][i]) or ('감귤' in data['상품명'][i]) or ('오렌지' in data['상품명'][i]) or ('한라봉' in data['상품명'][i]) or ('샤인머스켓' in data['상품명'][i]) or ('감말랭이' in data['상품명'][i]):
            data['중분류'][i] = '농산'
            data['소분류'][i] = '과일'
            
        elif ('고구마' in data['상품명'][i]) or ('옥수수' in data['상품명'][i]) or ('시래기' in data['상품명'][i]):
            data['중분류'][i] = '농산'
            data['소분류'][i] = '채소'
            
        elif ('햅쌀' in data['상품명'][i]) or ('쌀' in data['상품명'][i]):
            data['중분류'][i] = '농산'
            data['소분류'][i] = '쌀/잡곡/견과'
            
        # 수산
        elif ('생선' in data['상품명'][i]) or ('장어' in data['상품명'][i]) or ('우럭' in data['상품명'][i]) or ('메로' in data['상품명'][i]) or ('자연산돔' in data['상품명'][i]) or ('고등어' in data['상품명'][i]) or ('바다장어' in data['상품명'][i]) or ('홍어' in data['상품명'][i]) or ('수산물' in data['상품명'][i]) or ('조기' in data['상품명'][i]) or ('굴비' in data['상품명'][i]) or ('병어' in data['상품명'][i]) or ('가자미' in data['상품명'][i]) or ('옥돔' in data['상품명'][i]) or ('대구' in data['상품명'][i]) or ('갈치' in data['상품명'][i]):
            data['중분류'][i] = '수산'
            data['소분류'][i] = '생선류'
            
        elif ('꽃게' in data['상품명'][i]) or ('문어' in data['상품명'][i]) or ('랍스터' in data['상품명'][i]) or ('낙지' in data['상품명'][i]) or ('전복' in data['상품명'][i]) or ('골뱅이' in data['상품명'][i]) or ('참굴' in data['상품명'][i]) or ('오징어' in data['상품명'][i]) or ('꼬막' in data['상품명'][i]) or ('새우' in data['상품명'][i]):
            data['중분류'][i] = '수산'
            data['소분류'][i] = '해산물'
        
        elif ('황태' in data['상품명'][i]) or ('쥐치포' in data['상품명'][i]) or ('아구채' in data['상품명'][i]) or ('쥐포' in data['상품명'][i]) or ('과메기' in data['상품명'][i]):
            data['중분류'][i] = '수산'
            data['소분류'][i] = '건어물'
            
        elif ('매생이' in data['상품명'][i]) or ('전장김' in data['상품명'][i]) or ('도시락김' in data['상품명'][i]) or ('식탁앤김' in data['상품명'][i]) or ('부각' in data['상품명'][i]) or ('다시팩' in data['상품명'][i]):
            data['중분류'][i] = '수산'
            data['소분류'][i] = '해조류'
        
        # 축산
        elif ('LA갈비' in data['상품명'][i]) or ('소갈비살' in data['상품명'][i]) or ('치마살' in data['상품명'][i]) or ('우삼겹' in data['상품명'][i]) or ('우삽겹' in data['상품명'][i]) or ('안창살' in data['상품명'][i]):
            data['중분류'][i] = '축산'
            data['소분류'][i] = '소고기'
        
        elif ('순대' in data['상품명'][i]) or ('소곱창' in data['상품명'][i]) or ('닭발' in data['상품명'][i]):
            data['중분류'][i] = '축산'
            data['소분류'][i] = '축산가공식품'
            
        elif ('오리로스' in data['상품명'][i]) or ('오리' in data['상품명'][i]):
            data['중분류'][i] = '축산'
            data['소분류'][i] = '오리고기'
            
        elif ('곰탕' in data['상품명'][i]) or ('육포' in data['상품명'][i]) or ('뒷고기' in data['상품명'][i]) or ('곱창' in data['상품명'][i]) or ('한우 한판' in data['상품명'][i]) or ('소한마리' in data['상품명'][i]) or ('돼지왕구이' in data['상품명'][i]) or ('장조림' in data['상품명'][i]) or ('치킨스테이크' in data['상품명'][i]) or ('낙곱새' in data['상품명'][i]) or ('도가니탕' in data['상품명'][i]) or ('감자탕' in data['상품명'][i]) or ('국밥' in data['상품명'][i]) or ('삼계탕' in data['상품명'][i]) or ('탕요일' in data['상품명'][i]) or ('갈비탕' in data['상품명'][i]):
            data['중분류'][i] = '축산'
            data['소분류'][i] = '축산가공식품'
        
        
        # 가공식품
        # 김치/반찬
        elif ('김치' in data['상품명'][i]) or ('더덕무침' in data['상품명'][i]):
            data['중분류'][i] = '가공식품'
            data['소분류'][i] = '김치/반찬'
            
        elif ('젓갈' in data['상품명'][i]):
            data['중분류'][i] = '가공식품'
            data['소분류'][i] = '김치/반찬'
            
        # 과자/간식
        elif ('떡' in data['상품명'][i]) or ('호빵' in data['상품명'][i]):
            data['중분류'][i] = '가공식품'
            data['소분류'][i] = '과자/간식'
            
        elif ('곡물그대로' in data['상품명'][i]) or ('맛밤' in data['상품명'][i]):
            data['중분류'][i] = '가공식품'
            data['소분류'][i] = '과자/간식'
            
        elif ('강정' in data['상품명'][i]):
            data['중분류'][i] = '가공식품'
            data['소분류'][i] = '과자/간식'
            
        # 라면/면/스프
        elif ('콩국수' in data['상품명'][i]) or ('냉면' in data['상품명'][i]) or ('국수' in data['상품명'][i]):
            data['중분류'][i] = '가공식품'
            data['소분류'][i] = '라면/면/스프'
            
        # 조미료/소스/장류
        elif ('고춧가루' in data['상품명'][i]):
            data['중분류'][i] = '가공식품'
            data['소분류'][i] = '조미료/소스/장류'
            
        elif ('메주' in data['상품명'][i]):
            data['중분류'][i] = '가공식품'
            data['소분류'][i] = '조미료/소스/장류'
        
        # 커피/생수/음료
        elif ('두유' in data['상품명'][i])  or ('커피' in data['상품명'][i]):
            data['중분류'][i] = '가공식품'
            data['소분류'][i] = '커피/생수/음료'
        
        # 전통건강
        elif ('아카시아꿀' in data['상품명'][i]) or ('벌꿀' in data['상품명'][i]):
            data['중분류'][i] = '가공식품'
            data['소분류'][i] = '전통건강'
            
        elif ('배즙' in data['상품명'][i]):
            data['중분류'][i] = '가공식품'
            data['소분류'][i] = '전통건강'
            
        elif ('매실원액' in data['상품명'][i]) or ('머루원액' in data['상품명'][i]):
            data['중분류'][i] = '가공식품'
            data['소분류'][i] = '전통건강'
            
        elif ('해물철판' in data['상품명'][i]) or ('해장국' in data['상품명'][i]) or ('만두' in data['상품명'][i]) or ('마시는한끼' in data['상품명'][i]) or ('두부' in data['상품명'][i]) or ('재첩국' in data['상품명'][i]) or ('곤드레나물밥' in data['상품명'][i]) or ('선식' in data['상품명'][i]):
            data['중분류'][i] = '가공식품'
            data['소분류'][i] = '간편/즉석요리'
            
        # 기타
        else:
            data['중분류'][i] = '기타'
            data['소분류'][i] = '기타'

# %% [markdown]
# ## 분류 - 이미용

# %%
# 분류 시작!

for i in range(len(data)):
    if data['상품군'][i] == '이미용':
        
        # 헤어/바디
        if ('샴푸' in data['상품명'][i]) or ('실크테라피' in data['상품명'][i]):
            data['중분류'][i] = '헤어/바디'
            data['소분류'][i] = '헤어케어'
            
        elif ('트리트먼트' in data['상품명'][i]):
            data['중분류'][i] = '헤어/바디'
            data['소분류'][i] = '헤어케어'
            
        elif ('고데롤' in data['상품명'][i]) or ('볼륨스타일러' in data['상품명'][i]) or ('볼륨브러쉬' in data['상품명'][i]) or ('빗살 뿌리펌' in data['상품명'][i]) or ('셀프뿌리퍼머' in data['상품명'][i]):
            data['중분류'][i] = '헤어/바디'
            data['소분류'][i] = '헤어기기'
            
        elif ('볼륨 스프레이' in data['상품명'][i]) or ('염색제' in data['상품명'][i]) or ('헤어컬러' in data['상품명'][i]):
            data['중분류'][i] = '헤어/바디'
            data['소분류'][i] = '헤어케어'
            
        elif ('오일 워시' in data['상품명'][i]) or ('클린샤워' in data['상품명'][i]) or ('풋케어' in data['상품명'][i]):
            data['중분류'][i] = '헤어/바디'
            data['소분류'][i] = '바디케어'
            
            
        
        # 화장품/향수
        elif ('클렌져' in data['상품명'][i]) or ('클렌징패드' in data['상품명'][i]):
            data['중분류'][i] = '화장품/향수'
            data['소분류'][i] = '클렌징'
            
        elif ('남성' in data['상품명'][i]):
            data['중분류'][i] = '화장품/향수'
            data['소분류'][i] = '남성화장품'
            
        elif ('크림' in data['상품명'][i]) or ('세럼' in data['상품명'][i])or ('기초세트' in data['상품명'][i]) or ('링클 리프트' in data['상품명'][i]):
            data['중분류'][i] = '화장품/향수'
            data['소분류'][i] = '기초케어'
            
        elif ('립스틱' in data['상품명'][i]) or ('틴트브로우' in data['상품명'][i]) or ('아이라이너' in data['상품명'][i]) or ('아이스타일러' in data['상품명'][i]):
            data['중분류'][i] = '화장품/향수'
            data['소분류'][i] = '색조'
            
        elif ('선스틱' in data['상품명'][i]) or ('썬스틱' in data['상품명'][i]) or ('선쿠션' in data['상품명'][i]):
            data['중분류'][i] = '화장품/향수'
            data['소분류'][i] = '선케어'
            
        elif ('마스크' in data['상품명'][i]):
            data['중분류'][i] = '화장품/향수'
            data['소분류'][i] = '마스크/팩'
            
        elif ('쿠션' in data['상품명'][i]) or ('팩트' in data['상품명'][i]):
            data['중분류'][i] = '화장품/향수'
            data['소분류'][i] = '베이스'
            
        elif ('네일' in data['상품명'][i]):
            data['중분류'][i] = '화장품/향수'
            data['소분류'][i] = '네일'
            
        elif ('속눈썹세트' in data['상품명'][i]) or ('속눈썹' in data['상품명'][i]):
            data['중분류'][i] = '화장품/향수'
            data['소분류'][i] = '뷰티소품'
            
        elif ('모공기기' in data['상품명'][i]):
            data['중분류'][i] = '화장품/향수'
            data['소분류'][i] = '뷰티소품'
        
        # 기타
        else:
            data['중분류'][i] = '기타_이미용'
            data['소분류'][i] = '기타_이미용'

# %% [markdown]
# ## 분류 - 가전

# %%
for i in range(len(data)):
    if data['상품군'][i] == '가전':
        # TV/냉장고/세탁기
        if 'TV' in data['상품명'][i]:
            data['중분류'][i] = 'TV/냉장고/세탁기'
            data['소분류'][i] = 'TV'
        elif ('냉장고' in data['상품명'][i]) and ('김치' not in data['상품명'][i]):
            data['중분류'][i] = 'TV/냉장고/세탁기'
            data['소분류'][i] = '냉장고'
        elif '김치냉장고' in data['상품명'][i]:
            data['중분류'][i] = 'TV/냉장고/세탁기'
            data['소분류'][i] = '김치냉장고'
        elif ('세탁기' in data['상품명'][i]) or ('건조기' in data['상품명'][i]) or ('스타일러' in data['상품명'][i]):
            data['중분류'][i] = 'TV/냉장고/세탁기'
            data['소분류'][i] = '세탁/건조/스타일러'
        
        # 계절가전
        elif ('공기청정기' in data['상품명'][i]) or ('공청기' in data['상품명'][i]):
            data['중분류'][i] = '계절가전'
            data['소분류'][i] = '공기청정기'
        elif ('에어컨' in data['상품명'][i]) or (('무풍' in data['상품명'][i]) and ('슬림' in data['상품명'][i])):
            data['중분류'][i] = '계절가전'
            data['소분류'][i] = '에어컨'
            
        # 노트북/PC
        elif '노트북' in data['상품명'][i]:
            data['중분류'][i] = '노트북/PC'
            data['소분류'][i] = '노트북'
            
        # 생활가전
        elif ('청소기' in data['상품명'][i]) or ('로보킹' in data['상품명'][i]):
            data['중분류'][i] = '생활가전'
            data['소분류'][i] = '청소기'

# %% [markdown]
# ## 분류 - 생활용품

# %%
for i in range(len(data)):
    if data['상품군'][i] == '생활용품':
        # 건강/안마/실버
        if '패치' in data['상품명'][i]:
            data['중분류'][i] = '건강/안마/실버'
            data['소분류'][i] = '건강관리용품'
        elif '혈압계' in data['상품명'][i]:
            data['중분류'][i] = '건강/안마/실버'
            data['소분류'][i] = '건강측정용품'
        elif '저출력광선조사기' in data['상품명'][i]:
            data['중분류'][i] = '건강/안마/실버'
            data['소분류'][i] = '물리치료용품'
        elif '안전스틱' in data['상품명'][i]:
            data['중분류'][i] = '건강/안마/실버'
            data['소분류'][i] = '실버/복지용구'
        elif ('목 견인기기' in data['상품명'][i]) or ('마사지기' in data['상품명'][i]) or ('안마' in data['상품명'][i]):
            data['중분류'][i] = '건강/안마/실버'
            data['소분류'][i] = '안마용품'
        elif '바른자세밴드' in data['상품명'][i]:
            data['중분류'][i] = '건강/안마/실버'
            data['소분류'][i] = '의약외품'
            
        # 생활잡화
        elif '공구' in data['상품명'][i]:
            data['중분류'][i] = '생활잡화'
            data['소분류'][i] = '공구/철물/산업재'
        elif '교자상' in data['상품명'][i]:
            data['중분류'][i] = '생활잡화'
            data['소분류'][i] = '교자상/다용도테이블'
        elif ('금고' in data['상품명'][i]) or ('도어락' in data['상품명'][i]):
            data['중분류'][i] = '생활잡화'
            data['소분류'][i] = '보안용품'
        elif '마스크' in data['상품명'][i]:
            data['중분류'][i] = '생활잡화'
            data['소분류'][i] = '안전용품'
            
        # 세제/욕실/위생
        elif '치약' in data['상품명'][i]:
            data['중분류'][i] = '세제/욕실/위생'
            data['소분류'][i] = '구강용품/칫솔'
        elif '면도' in data['상품명'][i]:
            data['중분류'][i] = '세제/욕실/위생'
            data['소분류'][i] = '면도용품/면도기'
        elif '반신욕' in data['상품명'][i]:
            data['중분류'][i] = '세제/욕실/위생'
            data['소분류'][i] = '반신욕용품'
        elif ('화이트업' in data['상품명'][i]) or ('퍼퓸드몽드' in data['상품명'][i]) or ('섬유유연제' in data['상품명'][i]) or ('세제' in data['상품명'][i]):
            data['중분류'][i] = '세제/욕실/위생'
            data['소분류'][i] = '세탁세제/섬유유연제'
        elif '샤워기' in data['상품명'][i]:
            data['중분류'][i] = '세제/욕실/위생'
            data['소분류'][i] = '욕실/목욕용품'
            
        # 세탁/청소용품
        elif ('빨래' in data['상품명'][i]) or ('건조대' in data['상품명'][i]):
            data['중분류'][i] = '세탁/청소용품'
            data['소분류'][i] = '세탁/다림용품'
        elif ('굿터치클리너' in data['상품명'][i]) or ('거름통' in data['상품명'][i]) or ('뚜러킹' in data['상품명'][i]):
            data['중분류'][i] = '세탁/청소용품'
            data['소분류'][i] = '청소용품'
            
        # 수납/정리용품
        elif ('리빙박스' in data['상품명'][i]) or ('스피드랙 베이직' in data['상품명'][i]) or ('선반' in data['상품명'][i]):
            data['중분류'][i] = '수납/정리용품'
            data['소분류'][i] = '수납용품'
        elif ('옷걸이' in data['상품명'][i]) or ('행거' in data['상품명'][i]):
            data['중분류'][i] = '수납/정리용품'
            data['소분류'][i] = '행거'
    
        # 팬시/문구/악기/취미
        elif '예초기' in data['상품명'][i]:
            data['중분류'][i] = '팬시/문구/악기/취미'
            data['소분류'][i] = '원예/조경용품'
            
        # 가방/패션잡화
        elif '선글라스' in data['상품명'][i]:
            data['중분류'][i] = '가방/패션잡화'
            data['소분류'][i] = '패션 ACC'
            
        # 침실가구
        elif ('매트릭스' in data['상품명'][i]) or ('매트리스' in data['상품명'][i]) or ('메모리폼' in data['상품명'][i]):
            data['중분류'][i] = '침실가구'
            data['소분류'][i] = '침대/매트리스'
        elif ('접이식' in data['상품명'][i]) and ('매트' in data['상품명'][i]):
            data['중분류'][i] = '침실가구'
            data['소분류'][i] = '침대/매트리스'
        elif ('라텍스' in data['상품명'][i]) and ('배개' not in data['상품명'][i]):
            data['중분류'][i] = '침실가구'
            data['소분류'][i] = '침대/매트리스'
            
        # 거실가구
        elif '릴렉스 체어' in data['상품명'][i]:
            data['중분류'][i] = '거실가구'
            data['소분류'][i] = '소파'
            
        # 주방가구
        elif ('테이블' in data['상품명'][i]) and ('LP' not in data['상품명'][i]):
            data['중분류'][i] = '주방가구'
            data['소분류'][i] = '식탁'
            
        # 학생/사무용가구
        elif '의자' in data['상품명'][i]:
            data['중분류'][i] = '학생/사무용가구'
            data['소분류'][i] = '의자'
            
        # 침구/커튼/카페트
        elif ('베개' in data['상품명'][i]) or ('배개' in data['상품명'][i]):
            data['중분류'][i] = '침구/커튼/카페트'
            data['소분류'][i] = '침구세트'
        
        # 홈인테리어
        elif 'LED' in data['상품명'][i]:
            data['중분류'][i] = '홈인테리어'
            data['소분류'][i] = 'LED/전구/조명'
        elif '벽지' in data['상품명'][i]:
            data['중분류'][i] = '홈인테리어'
            data['소분류'][i] = '벽지/시트/스티커'
        elif '디퓨저' in data['상품명'][i]:
            data['중분류'][i] = '홈인테리어'
            data['소분류'][i] = '캔들/디퓨저'
            
        # 계절가전
        elif '공기청정기' in data['상품명'][i]:
            data['중분류'][i] = '계절가전'
            data['소분류'][i] = '공기청정기'
        elif '히터' in data['상품명'][i]:
            data['중분류'][i] = '계절가전'
            data['소분류'][i] = '난방용품'
        elif ('선풍기' in data['상품명'][i]) or ('에어쿨러' in data['상품명'][i]):
            data['중분류'][i] = '계절가전'
            data['소분류'][i] = '선풍기'
        elif ('서큘레이터' in data['상품명'][i]) or ('써큘레이터' in data['상품명'][i]) or ('윈큘레이터' in data['상품명'][i]):
            data['중분류'][i] = '계절가전'
            data['소분류'][i] = '써큘레이터'
        elif '에어컨' in data['상품명'][i]:
            data['중분류'][i] = '계절가전'
            data['소분류'][i] = '에어컨'
        elif ('카페트매트' in data['상품명'][i]) or ('온수매트' in data['상품명'][i]) or ('온열매트' in data['상품명'][i]):
            data['중분류'][i] = '계절가전'
            data['소분류'][i] = '온열매트'
        elif ('물매트' in data['상품명'][i]) or ('쿨잠패드' in data['상품명'][i]):
            data['중분류'][i] = '계절가전'
            data['소분류'][i] = '물매트/냉감패드'
            
        # 블랙박스/자동차
        elif '블랙박스' in data['상품명'][i]:
            data['중분류'][i] = '블랙박스/자동차'
            data['소분류'][i] = '블랙박스'
            
        # 생활가전
        elif '다리미' in data['상품명'][i]:
            data['중분류'][i] = '생활가전'
            data['소분류'][i] = '다리미'
        elif '비데' in data['상품명'][i]:
            data['중분류'][i] = '생활가전'
            data['소분류'][i] = '욕실가전'
        elif '청소기' in data['상품명'][i]:
            data['중분류'][i] = '생활가전'
            data['소분류'][i] = '청소기'
            
        # 영상/음향가전
        elif ('이어폰' in data['상품명'][i]) or ('LP턴테이블' in data['상품명'][i]):
            data['중분류'][i] = '영상/음향가전'
            data['소분류'][i] = '음향가전'
            
        # 등산/캠핑/낚시/자전거
        elif '낚시' in data['상품명'][i]:
            data['중분류'][i] = '등산/캠핑/낚시/자전거'
            data['소분류'][i] = '낚시용품'    
            
        # 자동차용품
        elif '코일카매트' in data['상품명'][i]:
            data['중분류'][i] = '자동차용품'
            data['소분류'][i] = '차량용 시트/매트'
            
        # 헬스/요가/수영/스키
        elif '워킹머신' in data['상품명'][i]:
            data['중분류'][i] = '헬스/요가/수영/스키'
            data['소분류'][i] = '런닝머신/워킹머신'
        elif ('스쿼트머신' in data['상품명'][i]) or ('플래티늄' in data['상품명'][i]):
            data['중분류'][i] = '헬스/요가/수영/스키'
            data['소분류'][i] = '웨이트기구'
            
        # 펫용품
        elif '바리캉' in data['상품명'][i]:
            data['중분류'][i] = '펫용품'
            data['소분류'][i] = '생활용품'

# %% [markdown]
# ## 분류 - 건강기능

# %%
for i in range(len(data)):
    if data['상품군'][i] == '건강기능':
        # 건강기능
        if '루테인' in data['상품명'][i]:
            data['중분류'][i] = '건강기능'
            data['소분류'][i] = '눈건강'
        elif ('모나코사놀' in data['상품명'][i]) or ('오메가' in data['상품명'][i]):
            data['중분류'][i] = '건강기능'
            data['소분류'][i] = '혈행건강'
        elif ('유산균' in data['상품명'][i]) and ('다이어트' not in data['상품명'][i]):
            data['중분류'][i] = '건강기능'
            data['소분류'][i] = '장건강'
        elif '바이오틱스' in data['상품명'][i]:
            data['중분류'][i] = '건강기능'
            data['소분류'][i] = '장건강'
        elif '레모나' in data['상품명'][i]:
            data['중분류'][i] = '건강기능'
            data['소분류'][i] = '면역'
        elif '전립' in data['상품명'][i]:
            data['중분류'][i] = '건강기능'
            data['소분류'][i] = '기타 건강기능'
            
        # 다이어트/이너뷰티
        elif ('레드빈' in data['상품명'][i]) or ('히비스커스' in data['상품명'][i]) or ('다이어트' in data['상품명'][i]):
            data['중분류'][i] = '다이어트/이너뷰티'
            data['소분류'][i] = '다이어트'
        elif ('밀싹 클렌즈' in data['상품명'][i]) or ('석류' in data['상품명'][i]) or ('콜라겐' in data['상품명'][i]):
            data['중분류'][i] = '다이어트/이너뷰티'
            data['소분류'][i] = '피부건강/이너뷰티'
            
        # 전통건강
        elif ('진액' in data['상품명'][i]) or ('해죽순' in data['상품명'][i]) or ('즙' in data['상품명'][i]):
            data['중분류'][i] = '전통건강'
            data['소분류'][i] = '건강즙'
        elif ('생식' in data['상품명'][i]) or ('두유' in data['상품명'][i]):
            data['중분류'][i] = '전통건강'
            data['소분류'][i] = '선식/생식'
        elif '홍합 환' in data['상품명'][i]:
            data['중분류'][i] = '전통건강'
            data['소분류'][i] = '파우더/환'
            
        # 홍삼
        elif '홍삼' in data['상품명'][i]:
            data['중분류'][i] = '홍삼'
            data['소분류'][i] = '홍삼'

# %% [markdown]
# ## 분류 - 잡화

# %%
for i in range(len(data)):
    if data['상품군'][i] == '잡화':
        # 가방/패션잡화
        if '벨트' in data['상품명'][i]:
            data['중분류'][i] = '가방/패션잡화'
            data['소분류'][i] = '벨트'
        elif ('모자' in data['상품명'][i]) or ('머플러' in data['상품명'][i]) or ('선글라스' in data['상품명'][i]) or ('양산' in data['상품명'][i]) or ('케이프' in data['상품명'][i]) or ('스카프' in data['상품명'][i]) or ('장갑' in data['상품명'][i]):
            data['중분류'][i] = '가방/패션잡화'
            data['소분류'][i] = '패션 ACC'
        elif '지갑' in data['상품명'][i]:
            data['중분류'][i] = '가방/패션잡화'
            data['소분류'][i] = '지갑'
        elif ('여행가방' in data['상품명'][i]) or ('캐리어' in data['상품명'][i]):
            data['중분류'][i] = '가방/패션잡화'
            data['소분류'][i] = '여행용가방'
        elif '백팩' in data['상품명'][i]:
            data['중분류'][i] = '가방/패션잡화'
            data['소분류'][i] = '캐주얼가방'
        elif ('백' in data['상품명'][i]) or ('리스틀릿' in data['상품명'][i]) or ('비텔로' in data['상품명'][i]) or ('사첼' in data['상품명'][i]) or ('숄더' in data['상품명'][i]) or ('캐리올' in data['상품명'][i]) or ('스퀘어 크로스' in data['상품명'][i]):
            data['중분류'][i] = '가방/패션잡화'
            data['소분류'][i] = '여성가방/핸드백'
        
        # 쥬얼리/시계
        elif ('시계' in data['상품명'][i]) or ('워치' in data['상품명'][i]):
            data['중분류'][i] = '쥬얼리/시계'
            data['소분류'][i] = '시계'
        elif ('골드바' in data['상품명'][i]) or ('목걸이' in data['상품명'][i]) or ('주얼리' in data['상품명'][i]) or ('팔찌' in data['상품명'][i]) or ('귀걸이' in data['상품명'][i]) or ('반지' in data['상품명'][i]) or ('순금' in data['상품명'][i]):
            data['중분류'][i] = '쥬얼리/시계'
            data['소분류'][i] = '쥬얼리'
        
        # 패션슈즈
        elif ('부츠' in data['상품명'][i]) and ('남성' in data['상품명'][i]):
            data['중분류'][i] = '패션슈즈'
            data['소분류'][i] = '남성화'
        elif ('슬립온' in data['상품명'][i]) and ('남성' in data['상품명'][i]):
            data['중분류'][i] = '패션슈즈'
            data['소분류'][i] = '남성화'
        elif ('캐쥬얼슈즈' in data['상품명'][i]) and ('남성' in data['상품명'][i]):
            data['중분류'][i] = '패션슈즈'
            data['소분류'][i] = '남성화'
        elif ('샌들' in data['상품명'][i]) and ('남성' in data['상품명'][i]):
            data['중분류'][i] = '패션슈즈'
            data['소분류'][i] = '남성화'
        elif ('방한화' in data['상품명'][i]) and ('남성' in data['상품명'][i]):
            data['중분류'][i] = '패션슈즈'
            data['소분류'][i] = '남성화'
        elif '남성화' in data['상품명'][i]:
            data['중분류'][i] = '패션슈즈'
            data['소분류'][i] = '남성화'
        elif ('부츠' in data['상품명'][i]) or ('캐쥬얼슈즈' in data['상품명'][i]) or ('샌들' in data['상품명'][i]) or ('로퍼' in data['상품명'][i]) or ('펌프스' in data['상품명'][i]) or ('방한화' in data['상품명'][i]):
            data['중분류'][i] = '패션슈즈'
            data['소분류'][i] = '여성화'
        elif '스니커즈' in data['상품명'][i]:
            data['중분류'][i] = '패션슈즈'
            data['소분류'][i] = '스니커즈'
        elif ('트레킹화' in data['상품명'][i]) or ('러닝화' in data['상품명'][i]) or ('워킹화' in data['상품명'][i]):
            data['중분류'][i] = '패션슈즈'
            data['소분류'][i] = '트레킹화/러닝화/워킹화'
        elif '슬립온' in data['상품명'][i]:
            data['중분류'][i] = '패션슈즈'
            data['소분류'][i] = '여성화'

# %% [markdown]
# ## 분류 - 가구

# %%
for i in range(len(data)):
    if data['상품군'][i] == '가구':
        # 침실가구
        if '붙박이장' in data['상품명'][i]:
            data['중분류'][i] = '침실가구'
            data['소분류'][i] = '붙박이장'
        elif ('침대' in data['상품명'][i]) or ('베드룸' in data['상품명'][i]) or ('매트리스' in data['상품명'][i]):
            data['중분류'][i] = '침실가구'
            data['소분류'][i] = '침대/매트리스'
        elif ('협탁' in data['상품명'][i]) or ('화장대' in data['상품명'][i]):
            data['중분류'][i] = '침실가구'
            data['소분류'][i] = '화장대/협탁'
            
        # 거실가구
        elif '거실장' in data['상품명'][i]:
            data['중분류'][i] = '거실가구'
            data['소분류'][i] = 'TV거실장'
        elif ('리클라이너' in data['상품명'][i]) or ('소파' in data['상품명'][i]) or ('흙카우치' in data['상품명'][i]) or ('스툴' in data['상품명'][i]):
            data['중분류'][i] = '거실가구'
            data['소분류'][i] = '소파'
        elif '테이블' in data['상품명'][i]:
            data['중분류'][i] = '거실가구'
            data['소분류'][i] = 'TV거실장'
            
        # 수납가구
        elif '서랍장' in data['상품명'][i]:
            data['중분류'][i] = '수납가구'
            data['소분류'][i] = '서랍장'
            
        # 시공/DIY
        elif ('하이바스' in data['상품명'][i]) or ('시공패키지' in data['상품명'][i]):
            data['중분류'][i] = '시공/DIY'
            data['소분류'][i] = '욕실/바스/타일'

# %% [markdown]
# ## 분류 - 침구

# %%
for i in range(len(data)):
    if data['상품군'][i] == '침구':
        # 침구/커튼/카페트
        if ('침구세트' in data['상품명'][i]) or ('침구 풀세트' in data['상품명'][i]):
            data['중분류'][i] = '침구/커튼/카페트'
            data['소분류'][i] = '침구세트'
        elif '커튼' in data['상품명'][i]:
            data['중분류'][i] = '침구/커튼/카페트'
            data['소분류'][i] = '커튼/블라인드'
        elif ('카페트' in data['상품명'][i]) or ('대자리' in data['상품명'][i]):
            data['중분류'][i] = '침구/커튼/카페트'
            data['소분류'][i] = '카페트/러그'

# %%
data.to_csv('data/test_data_02.csv', encoding='utf-8-sig')
